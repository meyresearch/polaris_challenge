# %% [markdown]
# # antiviral-potency-2025

# %% [markdown]
# What I intend to do here.
# - First get Polaris setup
# - Option 1: Pre-train on MPRO then fine-tune
# - Option 2: Use Active Learning to Select Optimal Training Samples

# %%
import sys
import os

# Navigate up from Polaris to THIS_STUDIO root
root_dir = os.path.abspath(os.path.join(os.getcwd(), "DD"))
sys.path.append(root_dir)

# Now import
from utils import *

# %%
CHALLENGE = "antiviral-potency-2025"
competition = po.load_competition(f"asap-discovery/{CHALLENGE}")
competition.cache()
# Out:
# [2025-03-02 18:31:11] INFO     The version of Polaris that was used to create the artifact (0.11.0) ]8;id=438776;file:///home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/polaris/_artifact.py\_artifact.py]8;;\:]8;id=642612;file:///home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/polaris/_artifact.py#92\92]8;;\
#                                is different from the currently installed version of Polaris
#                                (0.11.9).
#                       WARNING  You're loading data from a remote location. If the dataset is small     ]8;id=809019;file:///home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/polaris/dataset/_base.py\_base.py]8;;\:]8;id=369264;file:///home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/polaris/dataset/_base.py#181\181]8;;\
#                                enough, consider caching the dataset first using
#                                CompetitionSpecification.cache() for more performant data access.
# [18:31:11] Copying to destination                                                                      ]8;id=419716;file:///home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/polaris/dataset/_base.py\_base.py]8;;\:]8;id=16871;file:///home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/polaris/dataset/_base.py#380\380]8;;\
#            /home/zeus/.cache/polaris/datasets/e35da41e-9fde-464c-8fab-2203e02231ef/data.zarr
#            For large Zarr archives, this may take a while.                                             ]8;id=833379;file:///home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/polaris/dataset/_base.py\_base.py]8;;\:]8;id=636793;file:///home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/polaris/dataset/_base.py#381\381]8;;\
# [18:31:12]  Success: Copying Zarr keys                                                                ]8;id=224917;file:///home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/polaris/utils/context.py\context.py]8;;\:]8;id=884628;file:///home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/polaris/utils/context.py#53\53]8;;\
#             Success: Copying Zarr archive                                                             ]8;id=498388;file:///home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/polaris/utils/context.py\context.py]8;;\:]8;id=920442;file:///home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/polaris/utils/context.py#53\53]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# '/home/zeus/.cache/polaris/datasets/e35da41e-9fde-464c-8fab-2203e02231ef'

# %%
train, test = competition.get_train_test_split()

# %%
train

# %%
train.X
# Out:
# array(['COC[C@]1(C)C(=O)N(C2=CN=CC3=CC=CC=C23)C(=O)N1C |&1:3|',
#        'C=C(CN1CCC2=C(C=C(Cl)C=C2)C1C(=O)NC1=CN=CC2=CC=CC=C12)C(N)=O',
#        'CNC(=O)CN1C[C@]2(C[C@H](C)N(C3=CN=CC=C3C3CC3)C2=O)C2=C(C=CC(Cl)=C2)C1=O',
#        ..., 'CNC(=O)[C@H]1CCCN(C(=O)CC2=CN=CC3=CC=CC=C23)C1 |a:4|',
#        'C[C@H]1CCCN(C(=O)CC2=CN=CC3=CC=CC=C23)[C@H]1C |o1:1,19|',
#        'O=C(O)C[C@H]1CCCN(C(=O)CC2=CN=CC3=CC=CC=C23)C1 |a:4|'],
#       dtype='<U172')

# %%
Y = train.target_cols
Y
# Out:
# ['pIC50 (SARS-CoV-2 Mpro)', 'pIC50 (MERS-CoV Mpro)']

# %%
for i in range(len(train)):
    print(train[i])
# Out:
# ('COC[C@]1(C)C(=O)N(C2=CN=CC3=CC=CC=C23)C(=O)N1C |&1:3|', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.19})
# ('C=C(CN1CCC2=C(C=C(Cl)C=C2)C1C(=O)NC1=CN=CC2=CC=CC=C12)C(N)=O', {'pIC50 (SARS-CoV-2 Mpro)': 5.29, 'pIC50 (MERS-CoV Mpro)': 4.92})
# ('CNC(=O)CN1C[C@]2(C[C@H](C)N(C3=CN=CC=C3C3CC3)C2=O)C2=C(C=CC(Cl)=C2)C1=O', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.73})
# ('C=C(CN1CCC2=C(C=C(Cl)C=C2)C1C(=O)NC1=CN=CC2=CC=CC=C12)C(=O)OC', {'pIC50 (SARS-CoV-2 Mpro)': 6.11, 'pIC50 (MERS-CoV Mpro)': 4.9})
# ('C=C(CN1CCC2=C(C=C(Cl)C=C2)C1C(=O)NC1=CN=CC2=CC=CC=C12)C(=O)O', {'pIC50 (SARS-CoV-2 Mpro)': 5.62, 'pIC50 (MERS-CoV Mpro)': 4.81})
# ('C=C(CN(C(=O)C1CCOC2=C1C=C(Cl)C=C2)C1=CN=CC2=CC=CC=C12)C(=O)NC1=CC=CC=C1', {'pIC50 (SARS-CoV-2 Mpro)': 6.45, 'pIC50 (MERS-CoV Mpro)': 4.88})
# ('C=C(CN(C(=O)C1CCOC2=C1C=C(Cl)C=C2)C1=CN=CC2=CC=CC=C12)C(N)=O', {'pIC50 (SARS-CoV-2 Mpro)': 5.56, 'pIC50 (MERS-CoV Mpro)': 4.81})
# ('CCN1CC2(C1)C(=O)N(C1=CN=CC3=CC=CC=C13)C(=O)N2C', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.54})
# ('CCOC[C@]1(C)C(=O)N(C2=CN=CC3=CC=CC=C23)C(=O)N1C |&1:4|', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 8.16})
# ('CN1C(=O)N(C2=CN=CC3=CC=CC=C23)C(=O)C12CN(CC1=CC=CC=C1)C2', {'pIC50 (SARS-CoV-2 Mpro)': 5.4, 'pIC50 (MERS-CoV Mpro)': 4.84})
# ('CN1C(=O)N(C2=CN=CC3=CC=CC=C23)C(=O)C12CN(S(C)(=O)=O)C2', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.69})
# ('CC(=O)N1CC2(C1)C(=O)N(C1=CN=CC3=CC=CC=C13)C(=O)N2C', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.8})
# ('O=C1N[C@]2(C[C@@H](C3=C(Cl)C=CC=C3)C2)C(=O)N1C1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': 7.84, 'pIC50 (MERS-CoV Mpro)': 6.5})
# ('CN1CCN(C2=CC=CC=C2NC(=O)CN2CC3=CC=C(Cl)C=C3[C@H](C(=O)NC3=CN=CC4=CC=CC=C34)C2)CC1 |&1:24|', {'pIC50 (SARS-CoV-2 Mpro)': 5.78, 'pIC50 (MERS-CoV Mpro)': 4.99})
# ('O=C(CN1CC2=CC=C(Cl)C=C2[C@H](C(=O)NC2=CN=CC3=CC=CC=C23)C1)NCC1=CC=CC(Br)=C1 |&1:12|', {'pIC50 (SARS-CoV-2 Mpro)': 7.35, 'pIC50 (MERS-CoV Mpro)': 4.84})
# ('O=C(CN1CC2=CC=C(Cl)C=C2[C@H](C(=O)NC2=CN=CC3=CC=CC=C23)C1)NC1=CC=C(N2CCOCC2=O)C=C1 |&1:12|', {'pIC50 (SARS-CoV-2 Mpro)': 7.17, 'pIC50 (MERS-CoV Mpro)': 5.05})
# ('O=C(CN1CC2=CC=C(Cl)C=C2[C@H](C(=O)NC2=CN=CC3=CC=CC=C23)C1)NCC1=CC=CC=C1 |&1:12|', {'pIC50 (SARS-CoV-2 Mpro)': 7.22, 'pIC50 (MERS-CoV Mpro)': 5.37})
# ('O=C(CN1CC2=CC=C(Cl)C=C2[C@H](C(=O)NC2=CN=CC3=CC=CC=C23)C1)NCC1=CC=C(Br)C=C1 |&1:12|', {'pIC50 (SARS-CoV-2 Mpro)': 6.86, 'pIC50 (MERS-CoV Mpro)': 5.45})
# ('O=C(CN1CC2=CC=C(Cl)C=C2[C@H](C(=O)NC2=CN=CC3=CC=CC=C23)C1)NCC1=CC(Cl)=CC(Cl)=C1 |&1:12|', {'pIC50 (SARS-CoV-2 Mpro)': 7.16, 'pIC50 (MERS-CoV Mpro)': 5.31})
# ('O=C(CN1CC2=CC=C(Cl)C=C2[C@H](C(=O)NC2=CN=CC3=CC=CC=C23)C1)NCC1=CC=C2OCOC2=C1 |&1:12|', {'pIC50 (SARS-CoV-2 Mpro)': 6.95, 'pIC50 (MERS-CoV Mpro)': 5.4})
# ('O=C(CN1CC2=CC=C(Cl)C=C2[C@H](C(=O)NC2=CN=CC3=CC=CC=C23)C1)NCC1=CC=C(F)C=C1 |&1:12|', {'pIC50 (SARS-CoV-2 Mpro)': 7.11, 'pIC50 (MERS-CoV Mpro)': 5.38})
# ('O=C(CN1CC2=CC=C(Cl)C=C2[C@H](C(=O)NC2=CN=CC3=CC=CC=C23)C1)NCC1=CC=CC(Cl)=C1 |&1:12|', {'pIC50 (SARS-CoV-2 Mpro)': 7.02, 'pIC50 (MERS-CoV Mpro)': 5.52})
# ('CC(C)(NC(=O)CN1CC2=CC=C(Cl)C=C2[C@H](C(=O)NC2=CN=CC3=CC=CC=C23)C1)C1=CC=CC=C1 |&1:16|', {'pIC50 (SARS-CoV-2 Mpro)': 6.74, 'pIC50 (MERS-CoV Mpro)': 5.22})
# ('CC(=O)NC1=CC=C(NC(=O)CN2CC3=CC=C(Cl)C=C3[C@H](C(=O)NC3=CN=CC4=CC=CC=C34)C2)C=C1 |&1:21|', {'pIC50 (SARS-CoV-2 Mpro)': 7.47, 'pIC50 (MERS-CoV Mpro)': 5.27})
# ('CC(C)(C)N(CC1=CC=CC=C1)C(=O)CN1CC2=CC=C(Cl)C=C2[C@H](C(=O)NC2=CN=CC3=CC=CC=C23)C1 |&1:24|', {'pIC50 (SARS-CoV-2 Mpro)': 6.0, 'pIC50 (MERS-CoV Mpro)': 4.99})
# ('CC(=O)NC1=CC=C(N(C)C(=O)CN2CC3=CC=C(Cl)C=C3[C@H](C(=O)NC3=CN=CC4=CC=CC=C34)C2)C=C1 |&1:22|', {'pIC50 (SARS-CoV-2 Mpro)': 5.83, 'pIC50 (MERS-CoV Mpro)': 5.26})
# ('O=C(CN1CC2=CC=C(Cl)C=C2[C@H](C(=O)NC2=CN=CC3=CC=CC=C23)C1)NCC1=CC=C(CCO)C=C1 |&1:12|', {'pIC50 (SARS-CoV-2 Mpro)': 7.1, 'pIC50 (MERS-CoV Mpro)': 5.32})
# ('O=C(CN1CC2=CC=C(Cl)C=C2[C@H](C(=O)NC2=CN=CC3=CC=CC=C23)C1)NCC1=CC=CC(F)=C1 |&1:12|', {'pIC50 (SARS-CoV-2 Mpro)': 7.14, 'pIC50 (MERS-CoV Mpro)': 5.36})
# ('O=C(CN1CC2=CC=C(Cl)C=C2[C@H](C(=O)NC2=CN=CC3=CC=CC=C23)C1)NCCC1=CC=CC(Cl)=C1 |&1:12|', {'pIC50 (SARS-CoV-2 Mpro)': 7.21, 'pIC50 (MERS-CoV Mpro)': 5.22})
# ('CN(CCC1=CC=CC=C1)C(=O)CN1CC2=CC=C(Cl)C=C2[C@H](C(=O)NC2=CN=CC3=CC=CC=C23)C1 |&1:22|', {'pIC50 (SARS-CoV-2 Mpro)': 6.01, 'pIC50 (MERS-CoV Mpro)': 5.04})
# ('O=C1C(C2=CC(Cl)=CC=C2)=CN=C(S)N1C1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': 6.86, 'pIC50 (MERS-CoV Mpro)': 5.04})
# ('O=C(NC1=C(Cl)N=CC2=CC=CC=C12)C1CCOC2=C1C=C(Cl)C=C2', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.68})
# ('C=CC(=O)NC1=C(N(CC2=CC=CC(Cl)=C2)C(=O)CC2=CN=CC3=CC=CC=C23)C=CC=C1', {'pIC50 (SARS-CoV-2 Mpro)': 5.16, 'pIC50 (MERS-CoV Mpro)': 5.18})
# ('N#CC1=C(NC(=O)C2CCOC3=C2C=C(Cl)C=C3)C2=CC=CC=C2C=N1', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.06})
# ('C=CC(=O)NC(C(=O)NC1=CN=CC2=CC=CC=C12)C1=CC(Cl)=C(Cl)C=C1', {'pIC50 (SARS-CoV-2 Mpro)': 5.5, 'pIC50 (MERS-CoV Mpro)': 5.16})
# ('O=C1[C@H]2CCCCN2C(=O)N1C1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.26})
# ('O=C1[C@@H]2CCCCN2C(=O)N1C1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': 4.19, 'pIC50 (MERS-CoV Mpro)': 4.29})
# ('C[C@H]1CC[C@@H]2C(=O)N(C3=CN=CC4=CC=CC=C34)C(=O)N2C1 |o1:1,4|', {'pIC50 (SARS-CoV-2 Mpro)': 4.65, 'pIC50 (MERS-CoV Mpro)': 4.57})
# ('C[C@H]1CC[C@H]2C(=O)N(C3=CN=CC4=CC=CC=C34)C(=O)N2C1 |o1:1,4|', {'pIC50 (SARS-CoV-2 Mpro)': 4.37, 'pIC50 (MERS-CoV Mpro)': 4.69})
# ('C[C@H]1CC[C@@H]2C(=O)N(C3=CN=CC4=CC=CC=C34)C(=O)N2C1 |o1:1,4|', {'pIC50 (SARS-CoV-2 Mpro)': 4.21, 'pIC50 (MERS-CoV Mpro)': 4.34})
# ('C[C@H]1CC[C@H]2C(=O)N(C3=CN=CC4=CC=CC=C34)C(=O)N2C1 |o1:1,4|', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.76})
# ('O=C1N[C@]2(C[C@@H](C3=CC=C(Cl)C=C3)C2)C(=O)N1C1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': 7.04, 'pIC50 (MERS-CoV Mpro)': 5.11})
# ('O=C1N[C@]2(C[C@@H](C3=CC=CC=C3)C2)C(=O)N1C1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': 6.87, 'pIC50 (MERS-CoV Mpro)': 5.02})
# ('CO[C@H]1CCN2C(=O)N(C3=CN=CC4=CC=CC=C34)C(=O)[C@@H]2C1 |&1:2,21|', {'pIC50 (SARS-CoV-2 Mpro)': 4.03, 'pIC50 (MERS-CoV Mpro)': 4.28})
# ('O=C(O)CN1CC2=CC=C(Cl)C=C2[C@H](C(=O)NC2=CN=CC3=CC=CC=C23)C1 |&1:13|', {'pIC50 (SARS-CoV-2 Mpro)': 5.01, 'pIC50 (MERS-CoV Mpro)': 3.94})
# ('O=C(CN1CC2=CC=C(Cl)C=C2[C@H](C(=O)NC2=CN=CC3=CC=CC=C23)C1)NCC1=C(Cl)C=CC=C1Cl |&1:12|', {'pIC50 (SARS-CoV-2 Mpro)': 6.75, 'pIC50 (MERS-CoV Mpro)': 5.75})
# ('COC1=CC(CNC(=O)CN2CC3=CC=C(Cl)C=C3[C@H](C(=O)NC3=CN=CC4=CC=CC=C34)C2)=CC(OC)=C1 |&1:19|', {'pIC50 (SARS-CoV-2 Mpro)': 7.16, 'pIC50 (MERS-CoV Mpro)': 5.95})
# ('O=C(CN1CC2=CC=C(Cl)C=C2[C@H](C(=O)NC2=CN=CC3=CC=CC=C23)C1)NC1=CC=C2SC=NC2=C1 |&1:12|', {'pIC50 (SARS-CoV-2 Mpro)': 6.93, 'pIC50 (MERS-CoV Mpro)': 5.26})
# ('COC1=CC=C(CNC(=O)CN2CC3=CC=C(Cl)C=C3[C@H](C(=O)NC3=CN=CC4=CC=CC=C34)C2)C=C1OC |&1:20|', {'pIC50 (SARS-CoV-2 Mpro)': 6.94, 'pIC50 (MERS-CoV Mpro)': 5.72})
# ('O=C(CN1CC2=CC=C(Cl)C=C2[C@H](C(=O)NC2=CN=CC3=CC=CC=C23)C1)NC1=CC=CC=C1 |&1:12|', {'pIC50 (SARS-CoV-2 Mpro)': 7.01, 'pIC50 (MERS-CoV Mpro)': 5.65})
# ('CC1=CC=C2NC=C(CCNC(=O)CN3CC4=CC=C(Cl)C=C4[C@H](C(=O)NC4=CN=CC5=CC=CC=C45)C3)C2=C1 |&1:23|', {'pIC50 (SARS-CoV-2 Mpro)': 7.12, 'pIC50 (MERS-CoV Mpro)': 5.64})
# ('CCOC1=CC=C(CNC(=O)CN2CC3=CC=C(Cl)C=C3[C@H](C(=O)NC3=CN=CC4=CC=CC=C34)C2)C=C1 |&1:21|', {'pIC50 (SARS-CoV-2 Mpro)': 6.9, 'pIC50 (MERS-CoV Mpro)': 5.68})
# ('O=C(CN1CC2=CC=C(Cl)C=C2[C@H](C(=O)NC2=CN=CC3=CC=CC=C23)C1)NCCC1=CC=C(C(F)F)C=C1 |&1:12|', {'pIC50 (SARS-CoV-2 Mpro)': 7.3, 'pIC50 (MERS-CoV Mpro)': 5.99})
# ('CCOC1=CC=CC=C1CNC(=O)CN1CC2=CC=C(Cl)C=C2[C@H](C(=O)NC2=CN=CC3=CC=CC=C23)C1 |&1:23|', {'pIC50 (SARS-CoV-2 Mpro)': 6.94, 'pIC50 (MERS-CoV Mpro)': 6.04})
# ('O=C(CN1CC2=CC=C(Cl)C=C2[C@H](C(=O)NC2=CN=CC3=CC=CC=C23)C1)NCCC1=CC=C(C(F)(F)F)C=C1 |&1:12|', {'pIC50 (SARS-CoV-2 Mpro)': 7.15, 'pIC50 (MERS-CoV Mpro)': 5.8})
# ('CN1CCN(C2=CC=C(NC(=O)CN3CC4=CC=C(Cl)C=C4[C@H](C(=O)NC4=CN=CC5=CC=CC=C45)C3)C=C2F)CC1 |&1:22|', {'pIC50 (SARS-CoV-2 Mpro)': 7.24, 'pIC50 (MERS-CoV Mpro)': 5.28})
# ('CCC1=CC=C(CNC(=O)CN2CC3=CC=C(Cl)C=C3[C@H](C(=O)NC3=CN=CC4=CC=CC=C34)C2)C=C1 |&1:20|', {'pIC50 (SARS-CoV-2 Mpro)': 6.99, 'pIC50 (MERS-CoV Mpro)': 6.03})
# ('CCOC1=CC=CC(CNC(=O)CN2CC3=CC=C(Cl)C=C3[C@H](C(=O)NC3=CN=CC4=CC=CC=C34)C2)=C1 |&1:22|', {'pIC50 (SARS-CoV-2 Mpro)': 7.05, 'pIC50 (MERS-CoV Mpro)': 6.04})
# ('CC1=CC=C(CNC(=O)CN2CC3=CC=C(Cl)C=C3[C@H](C(=O)NC3=CN=CC4=CC=CC=C34)C2)C=C1 |&1:19|', {'pIC50 (SARS-CoV-2 Mpro)': 6.96, 'pIC50 (MERS-CoV Mpro)': 5.78})
# ('O=C(CN1CC2=CC=C(Cl)C=C2[C@H](C(=O)NC2=CN=CC3=CC=CC=C23)C1)NC(C1=CC=CC=C1)C1=CC=CC=C1 |&1:12|', {'pIC50 (SARS-CoV-2 Mpro)': 7.04, 'pIC50 (MERS-CoV Mpro)': 6.02})
# ('CN1CCN(C2=CC=C(NC(=O)CN3CC4=CC=C(Cl)C=C4[C@H](C(=O)NC4=CN=CC5=CC=CC=C45)C3)C=C2)CC1 |&1:22|', {'pIC50 (SARS-CoV-2 Mpro)': 6.69, 'pIC50 (MERS-CoV Mpro)': 5.64})
# ('COC1=CC=C(CNC(=O)CN2CC3=CC=C(Cl)C=C3[C@H](C(=O)NC3=CN=CC4=CC=CC=C34)C2)C=C1 |&1:20|', {'pIC50 (SARS-CoV-2 Mpro)': 7.08, 'pIC50 (MERS-CoV Mpro)': 5.87})
# ('CCN1CCN(C2=CC=C(NC(=O)CN3CC4=CC=C(Cl)C=C4[C@H](C(=O)NC4=CN=CC5=CC=CC=C45)C3)C=C2)CC1 |&1:23|', {'pIC50 (SARS-CoV-2 Mpro)': 7.55, 'pIC50 (MERS-CoV Mpro)': 5.67})
# ('COC1=CC=CC(CNC(=O)CN2CC3=CC=C(Cl)C=C3[C@H](C(=O)NC3=CN=CC4=CC=CC=C34)C2)=C1 |&1:21|', {'pIC50 (SARS-CoV-2 Mpro)': 7.08, 'pIC50 (MERS-CoV Mpro)': 5.96})
# ('COC1=CC=CC=C1CNC(=O)CN1CC2=CC=C(Cl)C=C2[C@H](C(=O)NC2=CN=CC3=CC=CC=C23)C1 |&1:22|', {'pIC50 (SARS-CoV-2 Mpro)': 6.96, 'pIC50 (MERS-CoV Mpro)': 5.79})
# ('O=C(CN1CC2=CC=C(Cl)C=C2[C@H](C(=O)NC2=CN=CC3=CC=CC=C23)C1)NCCC1=CC=C(Cl)C=C1Cl |&1:12|', {'pIC50 (SARS-CoV-2 Mpro)': 6.97, 'pIC50 (MERS-CoV Mpro)': 5.69})
# ('O=C(CN1CC2=CC=C(Cl)C=C2[C@H](C(=O)NC2=CN=CC3=CC=CC=C23)C1)NCCC1=CC=C(Cl)C(Cl)=C1 |&1:12|', {'pIC50 (SARS-CoV-2 Mpro)': 7.15, 'pIC50 (MERS-CoV Mpro)': 5.77})
# ('CCN1CCN(C2=CC=C(NC(=O)CN3CC4=CC=C(Cl)C=C4[C@H](C(=O)NC4=CN=CC5=CC=CC=C45)C3)C=C2F)CC1 |&1:23|', {'pIC50 (SARS-CoV-2 Mpro)': 7.43, 'pIC50 (MERS-CoV Mpro)': 5.45})
# ('CC1=CC=C(CCNC(=O)CN2CC3=CC=C(Cl)C=C3[C@H](C(=O)NC3=CN=CC4=CC=CC=C34)C2)C=C1 |&1:20|', {'pIC50 (SARS-CoV-2 Mpro)': 7.12, 'pIC50 (MERS-CoV Mpro)': 5.8})
# ('CO[C@H]1CC[C@@H]2C(=O)N(C3=CN=CC4=CC=CC=C34)C(=O)N2C1 |o1:2,5|', {'pIC50 (SARS-CoV-2 Mpro)': 4.22, 'pIC50 (MERS-CoV Mpro)': 4.23})
# ('CO[C@H]1CC[C@@H]2C(=O)N(C3=CN=CC4=CC=CC=C34)C(=O)N2C1 |o1:2,5|', {'pIC50 (SARS-CoV-2 Mpro)': 4.43, 'pIC50 (MERS-CoV Mpro)': 3.95})
# ('CO[C@H]1CC[C@H]2C(=O)N(C3=CN=CC4=CC=CC=C34)C(=O)N2C1 |o1:2,5|', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.29})
# ('CO[C@H]1CCN2C(=O)N(C3=CN=CC4=CC=CC=C34)C(=O)[C@H]2C1 |o1:2,21|', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.21})
# ('CO[C@H]1CC[C@H]2C(=O)N(C3=CN=CC4=CC=CC=C34)C(=O)N2C1 |o1:2,5|', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.22})
# ('CO[C@H]1CCN2C(=O)N(C3=CN=CC4=CC=CC=C34)C(=O)[C@H]2C1 |o1:2,21|', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.25})
# ('CN1CCN2C(=O)N(C3=CN=CC4=CC=CC=C34)C(=O)[C@@H]2C1', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.2})
# ('O=C1[C@@H]2CN(CC3=CC=CC=C3)CCN2C(=O)N1C1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': 5.54, 'pIC50 (MERS-CoV Mpro)': 4.3})
# ('CS(=O)(=O)N1CCN2C(=O)N(C3=CN=CC4=CC=CC=C34)C(=O)[C@@H]2C1', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.24})
# ('C[C@H]1CCN2C(=O)N(C3=CN=CC4=CC=CC=C34)C(=O)[C@@H]2C1 |o1:1,20|', {'pIC50 (SARS-CoV-2 Mpro)': 4.12, 'pIC50 (MERS-CoV Mpro)': 4.27})
# ('C[C@H]1CCN2C(=O)N(C3=CN=CC4=CC=CC=C34)C(=O)[C@@H]2C1 |o1:1,20|', {'pIC50 (SARS-CoV-2 Mpro)': 4.1, 'pIC50 (MERS-CoV Mpro)': 4.41})
# ('CCN1CCN2C(=O)N(C3=CN=CC4=CC=CC=C34)C(=O)[C@@H]2C1', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.28})
# ('CNC(=O)CN1C[C@@]2(C(=O)N(C3=CN=CC4=CC=CC=C34)C[C@H]2C)C2=CC(Cl)=CC=C2C1=O', {'pIC50 (SARS-CoV-2 Mpro)': 5.62, 'pIC50 (MERS-CoV Mpro)': 4.23})
# ('O=C1N[C@]2(C[C@H](C3=CC=CC=C3)C2)C(=O)N1C1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': 6.69, 'pIC50 (MERS-CoV Mpro)': 4.71})
# ('O=[S@](CC1=CC=CC(NC2=NC=NC3=C2C=CN3)=C1)C1=CC=CC=C1 |&1:1|', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.94})
# ('C[C@H]1CCN2C(=O)N(C3=CN=CC4=CC=CC=C34)C(=O)[C@H]2C1 |o1:1,20|', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.52})
# ('C[C@H]1CC[C@]2(CO1)NC(=O)N(C1=CN=CC3=CC=CC=C13)C2=O |&1:1,4|', {'pIC50 (SARS-CoV-2 Mpro)': 4.19, 'pIC50 (MERS-CoV Mpro)': 4.31})
# ('C[C@H]1CCN2C(=O)N(C3=CN=CC4=CC=CC=C34)C(=O)[C@H]2C1 |o1:1,20|', {'pIC50 (SARS-CoV-2 Mpro)': 4.12, 'pIC50 (MERS-CoV Mpro)': 3.96})
# ('CNC(=O)CN1C[C@]2(C(=O)N(C3=CN=CC4=CC=CC=C34)CC2(C)C)C2=C(C=CC(Cl)=C2)C1=O |o1:7|', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.26})
# ('CNC(=O)CN1C[C@]2(C(=O)N(C3=CN=CC4=CC=CC=C34)CC2(C)C)C2=C(C=CC(Cl)=C2)C1=O |o1:7|', {'pIC50 (SARS-CoV-2 Mpro)': 5.18, 'pIC50 (MERS-CoV Mpro)': 4.13})
# ('O=C(CN1CC2=C(C=C(Cl)C=C2)[C@H](C(=O)NC2=CN=CC3=CC=CC=C23)C1)NC1=NC=C(C(F)(F)F)C=C1 |&1:12|', {'pIC50 (SARS-CoV-2 Mpro)': 6.39, 'pIC50 (MERS-CoV Mpro)': 5.01})
# ('CC(C)(C)[C@H](NC(=O)C(F)(F)F)C(=O)N1C[C@H]2[C@@H]([C@H]1C(=O)N[C@H](C#N)C[C@@H]1CCNC1=O)C2(C)C', {'pIC50 (SARS-CoV-2 Mpro)': 8.68, 'pIC50 (MERS-CoV Mpro)': 7.25})
# ('C[C@H]1CCOC[C@@]12NC(=O)N(C1=CN=CC3=CC=CC=C13)C2=O |&1:1,6|', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.25})
# ('C[C@H]1CCOC[C@]12NC(=O)N(C1=CN=CC3=CC=CC=C13)C2=O |&1:1,6|', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.23})
# ('C[C@H]1OCCC[C@]12NC(=O)N(C1=CN=CC3=CC=CC=C13)C2=O |&1:1,&2:6|', {'pIC50 (SARS-CoV-2 Mpro)': 4.02, 'pIC50 (MERS-CoV Mpro)': 4.3})
# ('CC(=O)N1C[C@@H]2C[C@H]1[C@H]1C(=O)N(C3=CN=CC4=CC=CC=C34)C(=O)N21 |o1:8|', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.02})
# ('CNC(=O)CN1C[C@]2(C(=O)N(C3=CN=CC4=CC=CC=C34)C[C@H]2COC)C2=CC(Cl)=CC=C2C1=O |o1:7,22|', {'pIC50 (SARS-CoV-2 Mpro)': 5.73, 'pIC50 (MERS-CoV Mpro)': 4.36})
# ('CCS(=O)(=O)N1CC2(C1)C(=O)N(C1=CN=CC3=CC=CC=C13)C(=O)N2C', {'pIC50 (SARS-CoV-2 Mpro)': 4.76, 'pIC50 (MERS-CoV Mpro)': 4.18})
# ('CNC(=O)CN1C[C@]2(C(=O)N(C3=CN=CC4=CC=CC=C34)C[C@@H]2C)C2=CC(F)=CC=C2C1=O', {'pIC50 (SARS-CoV-2 Mpro)': 5.39, 'pIC50 (MERS-CoV Mpro)': 4.3})
# ('CN1C(=O)N(C2=CN=CC3=CC=CC=C23)C(=O)C12CN(S(=O)(=O)C1CC1)C2', {'pIC50 (SARS-CoV-2 Mpro)': 4.74, 'pIC50 (MERS-CoV Mpro)': 4.13})
# ('CNC(=O)CN1C[C@]2(C(=O)N(C3=CN=CC4=CC=CC=C34)C[C@H]2CC2=CC=CC=C2)C2=CC(Cl)=CC=C2C1=O |o1:7,22|', {'pIC50 (SARS-CoV-2 Mpro)': 5.81, 'pIC50 (MERS-CoV Mpro)': 4.75})
# ('CNC(=O)CN1C[C@@]2(C(=O)N(C3=CN=CC4=CC=CC=C34)C[C@H]2CC2=CC=CC=C2)C2=CC(Cl)=CC=C2C1=O |o1:7,22|', {'pIC50 (SARS-CoV-2 Mpro)': 5.43, 'pIC50 (MERS-CoV Mpro)': 4.28})
# ('CNC(=O)CN1C[C@]2(C(=O)N(C3=CN=CC4=CC=CC=C34)C[C@H]2CO)C2=CC(Cl)=CC=C2C1=O |o1:7,22|', {'pIC50 (SARS-CoV-2 Mpro)': 6.38, 'pIC50 (MERS-CoV Mpro)': 5.01})
# ('O=C1C[C@H](CC2=CC=CC=C2)CN1C1=CN=CC2=CC=CC=C12 |&1:3|', {'pIC50 (SARS-CoV-2 Mpro)': 4.91, 'pIC50 (MERS-CoV Mpro)': 4.38})
# ('CNC(=O)CN1C[C@]2(C(=O)N(C3=CN=CC4=CC=CC=C34)C[C@@H]2CC2=CC=CC=C2)C2=CC(Cl)=CC=C2C1=O', {'pIC50 (SARS-CoV-2 Mpro)': 5.2, 'pIC50 (MERS-CoV Mpro)': 4.09})
# ('O=C1N[C@]2(CCOC3=CC=NC=C32)C(=O)N1C1=CN=CC2=CC=CC=C12 |&1:3|', {'pIC50 (SARS-CoV-2 Mpro)': 4.27, 'pIC50 (MERS-CoV Mpro)': 4.27})
# ('NS(=O)(=O)C1=CC=C2OCC[C@]3(NC(=O)N(C4=CN=CC5=CC=CC=C45)C3=O)C2=C1 |&1:11|', {'pIC50 (SARS-CoV-2 Mpro)': 4.65, 'pIC50 (MERS-CoV Mpro)': 4.28})
# ('C[C@H]1COC[C@@]2(C1)NC(=O)N(C1=CN=CC3=CC=CC=C13)C2=O |&1:1,5|', {'pIC50 (SARS-CoV-2 Mpro)': 4.24, 'pIC50 (MERS-CoV Mpro)': 4.28})
# ('CC(=O)N1C[C@@H]2C[C@H]1[C@H]1C(=O)N(C3=CN=CC4=CC=CC=C34)C(=O)N21 |a:5,7,o1:8|', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.12})
# ('C=C(CN[C@]1(C(=O)NC2=CN=CC3=CC=CC=C23)CCOC2=CC=C(Cl)C=C21)C(=O)OC(C)(C)C', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 5.05})
# ('CN1C(=O)N(C2=CN=CC3=CC=CC=C23)C(=O)C12CN(S(=O)(=O)C1=CC=CC=C1)C2', {'pIC50 (SARS-CoV-2 Mpro)': 5.12, 'pIC50 (MERS-CoV Mpro)': 4.55})
# ('CC1(C)CCN(S(C)(=O)=O)C[C@]12NC(=O)N(C1=CN=CC3=CC=CC=C13)C2=O |o1:11|', {'pIC50 (SARS-CoV-2 Mpro)': 4.47, 'pIC50 (MERS-CoV Mpro)': 4.22})
# ('C[C@H]1COC[C@]2(C1)NC(=O)N(C1=CN=CC3=CC=CC=C13)C2=O |&1:1,5|', {'pIC50 (SARS-CoV-2 Mpro)': 5.21, 'pIC50 (MERS-CoV Mpro)': 4.85})
# ('NS(=O)(=O)OCC(=O)N1CCN(S(=O)(=O)C2=CSC=C2)[C@H](C(=O)NCC2=CC=CC=N2)C1 |&1:20|', {'pIC50 (SARS-CoV-2 Mpro)': 4.09, 'pIC50 (MERS-CoV Mpro)': 3.87})
# ('C=C(CN(C(=O)NC1=CN=CC2=CC=CC=C12)C1=CC=CC(Cl)=C1)C(=O)O', {'pIC50 (SARS-CoV-2 Mpro)': 5.49, 'pIC50 (MERS-CoV Mpro)': 4.54})
# ('O=C1[C@H](C2=CC=C(Cl)C(Cl)=C2)C[C@H](O)CN1C1=CN=CC2=CC=CC=C12 |&1:2,&2:12|', {'pIC50 (SARS-CoV-2 Mpro)': 5.47, 'pIC50 (MERS-CoV Mpro)': 4.31})
# ('O=C(CCl)N[C@H](C1=CC=CC(Cl)=C1)C1=NC=CS1 |&1:5|', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.25})
# ('CNS(=O)(=O)OCC(=O)N1CCN(CC2=CC=CC(Cl)=C2)[C@H](CC(C)C)C1 |&1:21|', {'pIC50 (SARS-CoV-2 Mpro)': 5.78, 'pIC50 (MERS-CoV Mpro)': 5.21})
# ('C=C(CN(C(=O)[C@H]1CCOC2=CC=C(Cl)C=C21)C1=CN=CC2=CC=CC=C12)C(=O)N1CCCCC1 |&1:6|', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.25})
# ('C[C@H](NC(=O)COS(N)(=O)=O)C1=CC(Cl)=CC(C2=CC=C(S(N)(=O)=O)C=C2)=C1 |&1:1|', {'pIC50 (SARS-CoV-2 Mpro)': 5.75, 'pIC50 (MERS-CoV Mpro)': 4.26})
# ('CC(C)C[C@H]1CN(C(=O)COS(N)(=O)=O)CCN1CC1=CC=CC(Cl)=C1 |&1:4|', {'pIC50 (SARS-CoV-2 Mpro)': 5.17, 'pIC50 (MERS-CoV Mpro)': 5.08})
# ('CC(C)C[C@H]1CN(C(=O)COS(=O)(=O)N(C)C)CCN1CC1=CC=CC(Cl)=C1 |&1:4|', {'pIC50 (SARS-CoV-2 Mpro)': 5.99, 'pIC50 (MERS-CoV Mpro)': 4.02})
# ('C=C(CN(C(=O)NC1=CN=CC2=CC=CC=C12)C1=CC=CC(Cl)=C1)C(=O)NCC', {'pIC50 (SARS-CoV-2 Mpro)': 5.77, 'pIC50 (MERS-CoV Mpro)': 4.58})
# ('C=C(CN(C(=O)NC1=CN=CC2=CC=CC=C12)C1=CC=CC(Cl)=C1)C(N)=O', {'pIC50 (SARS-CoV-2 Mpro)': 5.19, 'pIC50 (MERS-CoV Mpro)': 4.39})
# ('C[C@H]1CC[C@]2(CN1S(C)(=O)=O)NC(=O)N(C1=CN=CC3=CC=CC=C13)C2=O |&1:1,4|', {'pIC50 (SARS-CoV-2 Mpro)': 4.45, 'pIC50 (MERS-CoV Mpro)': 4.72})
# ('O=C1N[C@H](CC2=CC=CC=C2)C(=O)N1C1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': 4.5, 'pIC50 (MERS-CoV Mpro)': 4.87})
# ('CNC(=O)CN1C[C@]2(C(=O)N(C3=CN=CC4=CC=CC=C34)C[C@H]2CO)C2=CC(Cl)=CC=C2C1=O |o1:7,o2:22|', {'pIC50 (SARS-CoV-2 Mpro)': 6.47, 'pIC50 (MERS-CoV Mpro)': 5.36})
# ('O=C1C[C@H](CC2=CC=CC=C2)C(=O)N1C1=CN=CC2=CC=CC=C12 |&1:3|', {'pIC50 (SARS-CoV-2 Mpro)': 4.62, 'pIC50 (MERS-CoV Mpro)': 3.85})
# ('O=C1N[C@H](CC2CC2)C(=O)N1C1=CN=CC2=CC=CC=C12 |&1:3|', {'pIC50 (SARS-CoV-2 Mpro)': 4.31, 'pIC50 (MERS-CoV Mpro)': 4.36})
# ('CNC(=O)CN1C[C@@]2(C(=O)N(C3=CN=CC4=CC=CC=C34)C[C@@H]2CC2=CC=CC=C2)C2=CC(Cl)=CC=C2C1=O', {'pIC50 (SARS-CoV-2 Mpro)': 7.16, 'pIC50 (MERS-CoV Mpro)': 5.98})
# ('O=C1N[C@@H](CC2=CC=CC=C2)C(=O)N1C1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': 4.4, 'pIC50 (MERS-CoV Mpro)': 4.36})
# ('NC(=O)C1=CC=C2OCC[C@]3(NC(=O)N(C4=CN=CC5=CC=CC=C45)C3=O)C2=C1 |&1:10|', {'pIC50 (SARS-CoV-2 Mpro)': 4.85, 'pIC50 (MERS-CoV Mpro)': 4.34})
# ('C=C(CN(C(=O)[C@H]1CCOC2=CC=C(Cl)C=C21)C1=CN=CC2=CC=CC=C12)C(=O)NC1=CC=C(Cl)C=C1 |&1:6|', {'pIC50 (SARS-CoV-2 Mpro)': 5.18, 'pIC50 (MERS-CoV Mpro)': 4.33})
# ('CC(=O)N1C[C@@]2(CC[C@H]1C)NC(=O)N(C1=CN=CC3=CC=CC=C13)C2=O |&1:5,8|', {'pIC50 (SARS-CoV-2 Mpro)': 4.36, 'pIC50 (MERS-CoV Mpro)': 4.44})
# ('CN1C(=O)N(C2=CN=CC3=CC=CC=C23)C(=O)[C@@H]1CC1=CC=CC=C1', {'pIC50 (SARS-CoV-2 Mpro)': 4.06, 'pIC50 (MERS-CoV Mpro)': nan})
# ('C[C@H]1CC[C@@]2(CN1S(C)(=O)=O)NC(=O)N(C1=CN=CC3=CC=CC=C13)C2=O |&1:1,4|', {'pIC50 (SARS-CoV-2 Mpro)': 4.12, 'pIC50 (MERS-CoV Mpro)': 4.31})
# ('CN1N=CC2=CN=CC(NC(=O)[C@H]3CNS(=O)(=O)C4=CC=C(Cl)C=C43)=C21 |o1:12|', {'pIC50 (SARS-CoV-2 Mpro)': 6.06, 'pIC50 (MERS-CoV Mpro)': 4.2})
# ('CN1N=CC2=CN=CC(NC(=O)[C@H]3CNS(=O)(=O)C4=CC=C(Cl)C=C43)=C21 |o1:12|', {'pIC50 (SARS-CoV-2 Mpro)': 5.07, 'pIC50 (MERS-CoV Mpro)': 4.76})
# ('CN1C(CC2=CC=CC=C2)=NN(C2=CN=CC3=CC=CC=C23)C1=O', {'pIC50 (SARS-CoV-2 Mpro)': 5.04, 'pIC50 (MERS-CoV Mpro)': 4.43})
# ('CNS(=O)(=O)OCC(=O)N[C@H](C)C1=CC(Cl)=CC(C2=CC=C(S(N)(=O)=O)C=C2)=C1 |&1:10|', {'pIC50 (SARS-CoV-2 Mpro)': 5.76, 'pIC50 (MERS-CoV Mpro)': 4.19})
# ('C=C(CN(C(=O)[C@H]1CCOC2=CC=C(Cl)C=C21)C1=CN=CC2=CC=CC=C12)C(=O)NCC1=CC=CC=C1 |&1:6|', {'pIC50 (SARS-CoV-2 Mpro)': 5.24, 'pIC50 (MERS-CoV Mpro)': 5.23})
# ('CC(=O)N1C[C@]2(CC[C@H]1C)NC(=O)N(C1=CN=CC3=CC=CC=C13)C2=O |&1:5,8|', {'pIC50 (SARS-CoV-2 Mpro)': 4.21, 'pIC50 (MERS-CoV Mpro)': 4.34})
# ('CNC(=O)CN1C[C@]2(C(=O)N(C3=CN=CC4=CC=CC=C34)CC23CC3)C2=CC(Cl)=CC=C2C1=O |&1:7|', {'pIC50 (SARS-CoV-2 Mpro)': 6.1, 'pIC50 (MERS-CoV Mpro)': 4.74})
# ('O=C1C[C@H](CC2CC2)CN1C1=CN=CC2=CC=CC=C12 |&1:3|', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 3.58})
# ('C=C(CN(C(=O)[C@H]1CCOC2=CC=C(Cl)C=C21)C1=CN=CC2=CC=CC=C12)C(=O)N(C)C1=CC=CC=C1 |&1:6|', {'pIC50 (SARS-CoV-2 Mpro)': 5.55, 'pIC50 (MERS-CoV Mpro)': 3.94})
# ('CN1C=NC(CN2C(=O)N/C(=N\\C3=CC4=CN(C)N=C4C=C3Cl)N(CC3=CC(F)=C(F)C=C3F)C2=O)=N1', {'pIC50 (SARS-CoV-2 Mpro)': 8.43, 'pIC50 (MERS-CoV Mpro)': 6.46})
# ('CCCCNC(=O)C1=CN=C([C@H](NC(=O)CCl)C2=CC=CC(Cl)=C2)S1 |&1:11|', {'pIC50 (SARS-CoV-2 Mpro)': 5.25, 'pIC50 (MERS-CoV Mpro)': 4.32})
# ('CN1C(=O)N(C2=CN=CC3=CC=CC=C23)C(=O)[C@H]1CC1=CC=CC=C1', {'pIC50 (SARS-CoV-2 Mpro)': 4.06, 'pIC50 (MERS-CoV Mpro)': 4.46})
# ('O=C1C[C@H](CC2=CC=CC=C2Cl)CN1C1=CN=CC2=CC=CC=C12 |&1:3|', {'pIC50 (SARS-CoV-2 Mpro)': 5.14, 'pIC50 (MERS-CoV Mpro)': 4.32})
# ('COC1=CC=CC(CNC(=O)CN2C[C@]3(C(=O)N(C4=CN=CC5=CC=CC=C45)C[C@@H]3C)C3=CC=CC=C3C2=O)=C1', {'pIC50 (SARS-CoV-2 Mpro)': 4.59, 'pIC50 (MERS-CoV Mpro)': 4.3})
# ('O=C1N[C@]2(C[C@@H](C3=C(F)C=CC=C3F)C2)C(=O)N1C1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': 7.06, 'pIC50 (MERS-CoV Mpro)': 5.4})
# ('O=C1N[C@@]2(CC[C@H](C3=CC=CC=C3)OC2)C(=O)N1C1=CN=CC2=CC=CC=C12 |&1:3,6|', {'pIC50 (SARS-CoV-2 Mpro)': 5.2, 'pIC50 (MERS-CoV Mpro)': 4.34})
# ('O=C1N[C@]2(CC[C@H](C3=CC=CC=C3)OC2)C(=O)N1C1=CN=CC2=CC=CC=C12 |&1:3,6|', {'pIC50 (SARS-CoV-2 Mpro)': 5.69, 'pIC50 (MERS-CoV Mpro)': 4.67})
# ('COC1=CC=CC(CNC(=O)CN2C[C@@]3(C(=O)N(C4=CN=CC5=CC=CC=C45)C[C@@H]3C)C3=CC=CC=C3C2=O)=C1', {'pIC50 (SARS-CoV-2 Mpro)': 6.31, 'pIC50 (MERS-CoV Mpro)': 5.87})
# ('O=C1C[C@H](CC2=CC=CC=C2)NN1C1=CN=CC2=CC=CC=C12 |&1:3|', {'pIC50 (SARS-CoV-2 Mpro)': 5.16, 'pIC50 (MERS-CoV Mpro)': 4.31})
# ('O=C(NCC1=CC=CC=N1)[C@H]1CN(C(=O)COS(=O)(=O)NC2=CC=CC=C2)CCN1S(=O)(=O)C1=CSC=C1 |&1:10|', {'pIC50 (SARS-CoV-2 Mpro)': 4.75, 'pIC50 (MERS-CoV Mpro)': 4.18})
# ('CNS(=O)(=O)OCC(=O)N1CCN(S(=O)(=O)C2=CSC=C2)[C@H](C(=O)NCC2=CC=CC=N2)C1 |&1:21|', {'pIC50 (SARS-CoV-2 Mpro)': 4.79, 'pIC50 (MERS-CoV Mpro)': nan})
# ('CC1=CN=CC(CC(=O)NC2=CN=CC3=CC=CC=C23)=C1', {'pIC50 (SARS-CoV-2 Mpro)': 4.99, 'pIC50 (MERS-CoV Mpro)': 3.8})
# ('O=C(C[C@H]1CCCC(F)(F)C1)NC1=CN=CC2=CC=CC=C12 |&1:3|', {'pIC50 (SARS-CoV-2 Mpro)': 5.23, 'pIC50 (MERS-CoV Mpro)': 4.74})
# ('CC1=CC=C(CC(=O)NC2=CN=CC3=CC=CC=C23)C(F)=C1F', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 5.06})
# ('O=C(CC1=C(Cl)C(Cl)=CC=C1)NC1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 5.03})
# ('COC1=CC=C(C)C=C1CC(=O)NC1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': 5.25, 'pIC50 (MERS-CoV Mpro)': 4.38})
# ('CC1=CC=CC(CC(=O)NC2=CN=CC3=CC=CC=C23)=C1Cl', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.38})
# ('CC1=CC(F)=CC(CC(=O)NC2=CN=CC3=CC=CC=C23)=C1', {'pIC50 (SARS-CoV-2 Mpro)': 5.79, 'pIC50 (MERS-CoV Mpro)': 5.33})
# ('O=C1C[C@H](C(=O)NC2=CN=CC3=CC=CC=C23)C2=CC=CC=C2N1 |&1:3|', {'pIC50 (SARS-CoV-2 Mpro)': 4.65, 'pIC50 (MERS-CoV Mpro)': 3.78})
# ('O=C(CC1=C(F)C=C(F)C(F)=C1)NC1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': 5.69, 'pIC50 (MERS-CoV Mpro)': 5.35})
# ('O=C(CC1=C(F)C(F)=CC(F)=C1F)NC1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 5.01})
# ('CC1=CC=C(F)C(CC(=O)NC2=CN=CC3=CC=CC=C23)=C1', {'pIC50 (SARS-CoV-2 Mpro)': 5.29, 'pIC50 (MERS-CoV Mpro)': 5.36})
# ('C[C@H]1CN(C2=CN=CC3=CC=CC=C23)C(=O)[C@@]12CN(CC(=O)NCC1=CC=NN1C)C(=O)C1=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': 5.82, 'pIC50 (MERS-CoV Mpro)': 5.02})
# ('C[C@H]1CN(C2=CN=CC3=CC=CC=C23)C(=O)[C@@]12CN(CC(=O)NCC1=NN(C)C=C1)C(=O)C1=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': 5.59, 'pIC50 (MERS-CoV Mpro)': 5.12})
# ('O=C(CC1=CC(F)=CN=C1)NC1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': 5.33, 'pIC50 (MERS-CoV Mpro)': 4.18})
# ('COC1=CC=CC(CNC(=O)CN2C[C@@]3(C(=O)N(C4=CN=CC5=CC=CC=C45)C[C@@H]3C)C3=CC(Cl)=CC=C3C2=O)=C1', {'pIC50 (SARS-CoV-2 Mpro)': 7.16, 'pIC50 (MERS-CoV Mpro)': 6.6})
# ('CC1=CC=C(F)C=C1C(F)(F)C(=O)NC1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': 5.0, 'pIC50 (MERS-CoV Mpro)': 3.84})
# ('O=C(NC1=CN=CC2=CC=CC=C12)C(F)(F)C1=CC=C(F)C(F)=C1', {'pIC50 (SARS-CoV-2 Mpro)': 5.16, 'pIC50 (MERS-CoV Mpro)': 3.88})
# ('CC(F)(F)[C@H](C(=O)NC1=CN=CC2=CC=CC=C12)C1=CC=CC=C1 |&1:4|', {'pIC50 (SARS-CoV-2 Mpro)': 4.91, 'pIC50 (MERS-CoV Mpro)': 3.95})
# ('O=C(NC1=CN=CC2=CC=CC=C12)C(F)(F)C1=CC(F)=CC(F)=C1', {'pIC50 (SARS-CoV-2 Mpro)': 5.53, 'pIC50 (MERS-CoV Mpro)': 4.16})
# ('O=C(CC1=CC(F)=CC=C1F)NC1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': 5.69, 'pIC50 (MERS-CoV Mpro)': 4.58})
# ('O=C(CC1=C(F)C(F)=CC=C1)NC1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': 4.66, 'pIC50 (MERS-CoV Mpro)': 4.95})
# ('O=C(CC1=CC=CC=C1F)NC1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': 4.44, 'pIC50 (MERS-CoV Mpro)': 1.3})
# ('CC[C@H](C(=O)NC1=CN=CC2=CC=CC=C12)C1=CC=CC=C1 |&1:2|', {'pIC50 (SARS-CoV-2 Mpro)': 5.03, 'pIC50 (MERS-CoV Mpro)': 3.95})
# ('CC1=CC(F)=CC=C1C(F)(F)C(=O)NC1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': 4.56, 'pIC50 (MERS-CoV Mpro)': 2.43})
# ('C[C@H]1COC2=CC=CC=C2[C@H]1C(=O)NC1=CN=CC2=CC=CC=C12 |&1:1,&2:10|', {'pIC50 (SARS-CoV-2 Mpro)': 4.71, 'pIC50 (MERS-CoV Mpro)': 4.77})
# ('CC1=CC=C(F)C=C1CC(=O)NC1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': 5.73, 'pIC50 (MERS-CoV Mpro)': 4.44})
# ('O=C(CC1=CC(F)=CC=C1Cl)NC1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': 5.56, 'pIC50 (MERS-CoV Mpro)': 4.54})
# ('CC1=CC2=C(C=C1C)[C@H](C(=O)NC1=CN=CC3=CC=CC=C13)CO2 |&1:8|', {'pIC50 (SARS-CoV-2 Mpro)': 5.34, 'pIC50 (MERS-CoV Mpro)': 5.29})
# ('O=C(NC1=CN=CC2=CC=CC=C12)[C@H](CC(F)(F)F)C1=CC(F)=CC=C1 |&1:13|', {'pIC50 (SARS-CoV-2 Mpro)': 5.2, 'pIC50 (MERS-CoV Mpro)': 4.1})
# ('C[C@H](C(=O)NC1=CN=CC2=CC=CC=C12)C1=CC=CC(Cl)=C1 |&1:1|', {'pIC50 (SARS-CoV-2 Mpro)': 5.94, 'pIC50 (MERS-CoV Mpro)': 4.62})
# ('CC1=CC=CC(CC(=O)NC2=CN=CC3=CC=CC=C23)=C1F', {'pIC50 (SARS-CoV-2 Mpro)': 4.2, 'pIC50 (MERS-CoV Mpro)': 4.27})
# ('O=C(CC1=C(F)C(F)=CC=C1F)NC1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': 4.51, 'pIC50 (MERS-CoV Mpro)': 1.0})
# ('O=C(CC1=CC=C(F)C(F)=C1F)NC1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': 4.8, 'pIC50 (MERS-CoV Mpro)': 5.34})
# ('O=C(CC1=C(F)C=CC=C1F)NC1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.35})
# ('CC[C@H](C(=O)NC1=CN=CC2=CC=CC=C12)C1=CC(F)=C(F)C(F)=C1 |&1:2|', {'pIC50 (SARS-CoV-2 Mpro)': 6.11, 'pIC50 (MERS-CoV Mpro)': 4.53})
# ('CC1=CC=C([C@H](C(=O)NC2=CN=CC3=CC=CC=C23)C2CC2)C=C1 |&1:5|', {'pIC50 (SARS-CoV-2 Mpro)': 4.73, 'pIC50 (MERS-CoV Mpro)': 4.31})
# ('O=C(CC1=CC(F)=CC(F)=C1F)NC1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': 5.82, 'pIC50 (MERS-CoV Mpro)': 5.63})
# ('O=C(NC1=CN=CC2=CC=CC=C12)[C@H]1COC2=CC=C(F)C=C21 |&1:13|', {'pIC50 (SARS-CoV-2 Mpro)': 5.46, 'pIC50 (MERS-CoV Mpro)': 4.6})
# ('O=C(CC1=CC=C(F)C=C1F)NC1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': 4.6, 'pIC50 (MERS-CoV Mpro)': 5.0})
# ('O=C(CC1=CC(Cl)=CC=C1F)NC1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': 5.97, 'pIC50 (MERS-CoV Mpro)': 4.81})
# ('O=C(CC1=CC(F)=CC(F)=C1)NC1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': 6.19, 'pIC50 (MERS-CoV Mpro)': 4.88})
# ('O=C1N[C@]2(CCOC3=CC=CC=C32)C(=O)N1C1=CN=CC2=CC=CC=C12 |&1:3|', {'pIC50 (SARS-CoV-2 Mpro)': 4.82, 'pIC50 (MERS-CoV Mpro)': 4.63})
# ('CNC(=O)CN1C[C@@]2(C(=O)N(C3=CN=CC4=CC=CC=C34)C[C@@H]2C)C2=CC=C(F)C=C2C1=O', {'pIC50 (SARS-CoV-2 Mpro)': 6.28, 'pIC50 (MERS-CoV Mpro)': 5.35})
# ('O=C1N[C@]2(CCOC3=CC=C(CO)C=C32)C(=O)N1C1=CN=CC2=CC=CC=C12 |&1:3|', {'pIC50 (SARS-CoV-2 Mpro)': 4.87, 'pIC50 (MERS-CoV Mpro)': 4.52})
# ('CNC(=O)CN1C[C@]2(C(=O)N(C3=CN=CC4=CC=CC=C34)C[C@H]2CC2CC2)C2=CC(Cl)=CC=C2C1=O |o1:7,22|', {'pIC50 (SARS-CoV-2 Mpro)': 5.27, 'pIC50 (MERS-CoV Mpro)': 4.15})
# ('CCCCNC(=O)C1=CN=C([C@H](NC(=O)CCl)C2=CC=CC=C2)S1 |&1:11|', {'pIC50 (SARS-CoV-2 Mpro)': 4.72, 'pIC50 (MERS-CoV Mpro)': 4.73})
# ('COC1=CC=C(CNC2=CN=C([C@H](NC(=O)CCl)C3=CC=CC=C3)S2)C(OC)=C1 |&1:12|', {'pIC50 (SARS-CoV-2 Mpro)': 4.33, 'pIC50 (MERS-CoV Mpro)': 4.11})
# ('CNC(=O)CN1C[C@@]2(C(=O)N(C3=CN=CC=C3C3CC3)C[C@@H]2C)C2=CC(Cl)=CC=C2C1=O', {'pIC50 (SARS-CoV-2 Mpro)': 6.33, 'pIC50 (MERS-CoV Mpro)': 5.08})
# ('CN1N=CC(C2CCC2)=C1CNC(=O)C1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': 4.25, 'pIC50 (MERS-CoV Mpro)': 4.16})
# ('O=C(NCCC1=CNC2=NC=C(F)C=C12)C1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': 4.42, 'pIC50 (MERS-CoV Mpro)': 3.85})
# ('O=C(NCCC1=CNC2=CC(F)=CC=C12)C1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.05})
# ('CC(C)(NC(=O)C1=CN=CC2=CC=CC=C12)C1=CC=CC(C#N)=C1', {'pIC50 (SARS-CoV-2 Mpro)': 4.23, 'pIC50 (MERS-CoV Mpro)': 4.3})
# ('C[C@H](NC(=O)C1=CN=CC2=CC=CC=C12)C1=NC2=CC=CC=C2N1C |&1:1|', {'pIC50 (SARS-CoV-2 Mpro)': 4.06, 'pIC50 (MERS-CoV Mpro)': 3.84})
# ('O=C(C1=CN=CC2=CC=CC=C12)N1CC[C@H]1C1=CC=CC(F)=C1 |&1:15|', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.29})
# ('CNC(=O)CN1C[C@@]2(C(=O)N(C3=CN=CC4=CC=CC=C34)C[C@@H]2C)C2=CC=CC(F)=C2C1=O', {'pIC50 (SARS-CoV-2 Mpro)': 5.89, 'pIC50 (MERS-CoV Mpro)': 5.25})
# ('CC1=NC=C(CNC(=O)C2=CN=CC3=CC=CC=C23)N1C1=CC=CC=C1', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.1})
# ('CN(C(=O)C1=CN=CC2=CC=CC=C12)[C@H]1C2=CC=CC=C2C[C@H]1O', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.19})
# ('O=C(NCCC(=O)N1CCCCC1)C1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': 4.09, 'pIC50 (MERS-CoV Mpro)': 4.26})
# ('O=C(NCC1=CC=CC=C1N1C=CN=C1)C1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.24})
# ('CNC(=O)CN1C[C@@]2(C(=O)N(C3=CN=CC4=CC=CC=C34)C[C@@H]2C)C2=CN=CC=C2C1=O', {'pIC50 (SARS-CoV-2 Mpro)': 5.59, 'pIC50 (MERS-CoV Mpro)': 4.45})
# ('O=C(NCC1=CNC2=CC=C(F)C=C12)C1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': 4.72, 'pIC50 (MERS-CoV Mpro)': 3.42})
# ('CC1=CC=CC2=C1C=C(CNC(=O)C1=CN=CC3=CC=CC=C13)N2', {'pIC50 (SARS-CoV-2 Mpro)': 4.87, 'pIC50 (MERS-CoV Mpro)': 3.66})
# ('CN1C2=CC=CC=C2N(CCNC(=O)C2=CN=CC3=CC=CC=C23)S1(=O)=O', {'pIC50 (SARS-CoV-2 Mpro)': 4.15, 'pIC50 (MERS-CoV Mpro)': 4.3})
# ('O=C(NCC1=CC2=C(CCCC2)N=C1O)C1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': 4.46, 'pIC50 (MERS-CoV Mpro)': 4.32})
# ('CN(C(=O)C1=CC=CN=C1)[C@H]1C2=CC=CC=C2C[C@H]1O', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 5.23})
# ('CN(CC(=O)NC(C1=CC=CC=C1)C1=CC=CC=C1)C(=O)C1=CC=CN=C1', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.3})
# ('O=C(C1=CN=CC2=CC=CC=C12)N1CCCC[C@H]1C1=CC=CC(F)=C1 |&1:17|', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.38})
# ('CC1=NN(C2=CC=C(Cl)C=C2)C(NC(=O)C2=CN=CC3=CC=CC=C23)=C1C', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 7.88})
# ('CC1=C(CCNC(=O)C2=CN=CC3=CC=CC=C23)C2=CC(O)=CC=C2N1', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.23})
# ('O=C(NCCN1C(=O)CC2=CC=CC=C21)C1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.21})
# ('O=C(NCC1=NC2=CC(Cl)=CC=C2S1)C1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': 4.04, 'pIC50 (MERS-CoV Mpro)': 4.96})
# ('NC(=O)C1(NC(=O)C2=CN=CC3=CC=CC=C23)CC2=CC=CC=C2C1', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.25})
# ('O=C(NCCC1=CNC2=CC=C(Cl)C=C12)C1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': 4.91, 'pIC50 (MERS-CoV Mpro)': 4.08})
# ('CC1=CN=C2NC=C(CCNC(=O)C3=CN=CC4=CC=CC=C34)C2=C1', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.36})
# ('O=C(C1=CN=CC2=CC=CC=C12)N1CCCC[C@H]1C1=CC=CC=C1', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.39})
# ('CN1C(CNC(=O)C2=CN=CC3=CC=CC=C23)=NC2=CC=CC=C21', {'pIC50 (SARS-CoV-2 Mpro)': 4.07, 'pIC50 (MERS-CoV Mpro)': 3.58})
# ('O=C(N[C@H]1C2=CC=CC=C2C[C@H]1O)C1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 3.76})
# ('CN(CC1=CC=CC(O)=C1)C(=O)C1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 6.25})
# ('CN(CC1=NN(C2=CC=CC=C2)N=C1)C(=O)C1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 7.33})
# ('O=C(NCC1=CC=CC=C1N1C=CC=N1)C1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.29})
# ('CN(CC1=CC=C2C=CNC2=C1)C(=O)C1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.19})
# ('O=C(C1=CN=CC2=CC=CC=C12)N1CCC[C@H]1C1=CC=CC=C1', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.27})
# ('COC1=CC=C2NC=C(CCNC(=O)C3=CN=CC4=CC=CC=C34)C2=C1', {'pIC50 (SARS-CoV-2 Mpro)': 4.24, 'pIC50 (MERS-CoV Mpro)': 4.52})
# ('CN1CCN(C(=O)CCCNC(=O)C2=CN=CC3=CC=CC=C23)CC1', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.37})
# ('O=C(NCCC1=NC=CN1C1=CC=CC=C1)C1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.26})
# ('O=C(C1=CN=CC2=CC=CC=C12)N1CCC(CC2=CC=C(F)C=C2)CC1', {'pIC50 (SARS-CoV-2 Mpro)': 5.1, 'pIC50 (MERS-CoV Mpro)': 4.23})
# ('COC1=CC=C2OCC[C@@H](NC(=O)C3=CN=CC4=CC=CC=C34)C2=C1', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 3.9})
# ('CC1=CC=C([C@H](CO)NC(=O)C2=CN=CC3=CC=CC=C23)C=C1 |&1:5|', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.47})
# ('CN1N=C(CNC(=O)C2=CN=CC3=CC=CC=C23)C2=CC=CC=C2C1=O', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 3.61})
# ('CC1=NC=C2CC[C@H](NC(=O)C3=CN=CC4=CC=CC=C34)CN21 |&1:7|', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.15})
# ('O=C(NCCC1=CNC2=CC=C(F)C=C12)C1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': 4.82, 'pIC50 (MERS-CoV Mpro)': 3.82})
# ('O=C(NCCN1CCC2=CC=CC=C2C1=O)C1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.17})
# ('O=C(NC1CN(C2=CC=NC=C2)C1)C1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.33})
# ('O=C(N[C@H]1C2=CC=CC=C2C[C@@H]1O)C1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.35})
# ('O=C(NCC1=NC=CN1C1=CC=CC=C1)C1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.17})
# ('O=C(NCC1=CC=NN1C1=CC=CC=C1)C1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.21})
# ('O=C(NCCC1=CNC2=NC=C(Cl)C=C12)C1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': 4.32, 'pIC50 (MERS-CoV Mpro)': 4.06})
# ('C[C@@H](NC(=O)C1=CN=CC2=CC=CC=C12)C1=CSC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.48})
# ('O=C(NCC1=CSC2=CC=C(Cl)C=C12)C1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.12})
# ('O=C(NCC(=O)N1CCCC2=CC=CC=C21)C1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.24})
# ('O=C(C1=CN=CC2=CC=CC=C12)N1CC[C@H]1C1=CC=CC=C1', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.33})
# ('O=C(C1=CN=CC2=CC=CC=C12)N1CC[C@H]1C1=CC=CC=C1F |&1:15|', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.21})
# ('N#CC1=CC=CC=C1CNC(=O)C1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.0})
# ('O=C(NCC(=O)N1CCCC1)C1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 5.13})
# ('CN(CC1=NC2=CC=CC=C2N1C)C(=O)C1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.31})
# ('CN1C(CNC(=O)C2=CN=CC3=CC=CC=C23)=NC2=CC(F)=CC=C21', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.5})
# ('COC1=CC=C(O)C([C@H](C)NC(=O)C2=CN=CC3=CC=CC=C23)=C1 |&1:8|', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.3})
# ('O=C(NCCOC1=CC(Cl)=CC=N1)C1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': 4.8, 'pIC50 (MERS-CoV Mpro)': 3.65})
# ('O=C(N[C@@H]1C[C@H](O)C2=CC=CC=C21)C1=CN=CC2=CC=CC=C12 |&1:3,5|', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.5})
# ('O=C(NCC1=CC(=O)NC2=CC=CC=C12)C1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.15})
# ('CN(CC1=CC=CC(C#N)=C1)C(=O)C1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.18})
# ('O=C(NCCC1=CNC2=CN=CC=C12)C1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 3.92})
# ('O=C(NCC1=NC2=CC=CC=C2N1)C1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': 4.23, 'pIC50 (MERS-CoV Mpro)': 4.52})
# ('CC1=CC=C(F)C(CN(C)C(=O)C2=CN=CC3=CC=CC=C23)=C1', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.21})
# ('C[C@H](C1=CC=C(F)C=C1)N(C)C(=O)C1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.18})
# ('O=C1C(C2=CC=CC(Cl)=C2)=CN=CN1C1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': 5.78, 'pIC50 (MERS-CoV Mpro)': 4.76})
# ('O=C(C1=CN=CC2=CC=CC=C12)N1CCOC[C@H]1C1=CC=CC(Cl)=C1 |&1:17|', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.2})
# ('CC1=CC([C@H]2CCCN2C(=O)C2=CN=CC3=CC=CC=C23)=CC=N1 |&1:4|', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.16})
# ('CC1=CC=C(Cl)C([C@H]2CCCN2C(=O)C2=CN=CC3=CC=CC=C23)=C1 |&1:7|', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 9.0})
# ('CN(C(=O)C1=CN=CC2=CC=CC=C12)[C@H]1CC2=CC=CC=C2[C@H]1O |&1:14,22|', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.21})
# ('CC1=CC=C2NC=C(CCNC(=O)C3=CN=CC4=CC=CC=C34)C2=N1', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.25})
# ('CN(CCC1=CC=NC=C1)C(=O)C1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.37})
# ('COC1=CC=C(Cl)C=C1[C@H]1CCCCN1C(=O)C1=CN=CC2=CC=CC=C12 |&1:9|', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.31})
# ('CN(C(=O)C1=CN=CC2=CC=CC=C12)[C@H](C1=CC=CC(Cl)=C1)C1=CC=CC=N1 |&1:14|', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 3.84})
# ('CC1=NC=C(C2=CC=CC(Cl)=C2)C(=O)N1C1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': 4.8, 'pIC50 (MERS-CoV Mpro)': 4.91})
# ('O=C(C1=CN=CC2=CC=CC=C12)N1CCCC[C@H]1C1=CC=CC=N1 |&1:17|', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.29})
# ('O=C(N[C@H]1CCCN(C(=O)C2=CN=CC3=CC=CC=C23)C1)C1=CC=C(Cl)C=C1 |&1:3|', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.22})
# ('CCC1=CC=C2C(=C1)[C@H](NC(=O)C1=CN=CC3=CC=CC=C13)C(=O)N2C |&1:8|', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.28})
# ('O=C(C1=CN=CC2=CC=CC=C12)N1CCCC[C@H]1C1=CC=CC(Cl)=C1 |&1:17|', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.37})
# ('CC1=CC=CC=C1[C@H]1[C@H](O)CCN1C(=O)C1=CN=CC2=CC=CC=C12 |&1:7,&2:8|', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 3.7})
# ('O=C(C1=CN=CC2=CC=CC=C12)N1CCCC[C@H]1C1=CC=C(Cl)C=C1 |&1:17|', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.44})
# ('CN(CCC1=CC=CC=C1)C(=O)C1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.25})
# ('CC(C)C[C@H](NC(=O)OC1CC2(C1)CN(C(=O)CC1=CC=CC=C1)C2)C(=O)N[C@H](C=O)C[C@@H]1CCNC1=O', {'pIC50 (SARS-CoV-2 Mpro)': 4.2, 'pIC50 (MERS-CoV Mpro)': 4.7})
# ('CN(CC1=CN=C2C=CC=CN12)C(=O)C1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.94})
# ('CC(C)C[C@H]1CN(C(=O)COS(=O)(=O)N2CCN(C)CC2)CCN1CC1=CC=CC(Cl)=C1 |&1:4|', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 3.99})
# ('CC(C)C[C@H]1CN(C(=O)COS(=O)(=O)N2CCCC2)CCN1CC1=CC=CC(Cl)=C1 |&1:4|', {'pIC50 (SARS-CoV-2 Mpro)': 5.83, 'pIC50 (MERS-CoV Mpro)': 4.17})
# ('CC(C)C[C@H]1CN(C(=O)COS(=O)(=O)N2CCCCC2)CCN1CC1=CC=CC(Cl)=C1 |&1:4|', {'pIC50 (SARS-CoV-2 Mpro)': 6.41, 'pIC50 (MERS-CoV Mpro)': 4.86})
# ('CN1C[C@H](C(=O)NC2=CN=CC3=CC=CC=C23)C2=CC(Cl)=CC=C2C1=O |o1:3|', {'pIC50 (SARS-CoV-2 Mpro)': 5.17, 'pIC50 (MERS-CoV Mpro)': 4.13})
# ('CN1C[C@H](C(=O)NC2=CN=CC3=CC=CC=C23)C2=CC(Cl)=CC=C2C1=O |o1:3|', {'pIC50 (SARS-CoV-2 Mpro)': 6.65, 'pIC50 (MERS-CoV Mpro)': 5.69})
# ('CC(C)C[C@H]1CN(C(=O)COS(=O)(=O)N2CCOCC2)CCN1CC1=CC=CC(Cl)=C1 |&1:4|', {'pIC50 (SARS-CoV-2 Mpro)': 6.9, 'pIC50 (MERS-CoV Mpro)': 5.05})
# ('CNC(=O)CN1C[C@]2(C[C@H](COC)N(C3=CN=CC4=CC=CC=C34)C2=O)C2=CC(Cl)=CC=C2C1=O |&1:7,9|', {'pIC50 (SARS-CoV-2 Mpro)': 4.27, 'pIC50 (MERS-CoV Mpro)': 4.28})
# ('CN1C[C@H](C(=O)NC2=CN=CC3=CC=CC=C23)C2=CC(F)=CC=C2C1=O |o1:3|', {'pIC50 (SARS-CoV-2 Mpro)': 5.02, 'pIC50 (MERS-CoV Mpro)': 4.52})
# ('CN1C[C@H](C(=O)NC2=CN=CC3=CC=CC=C23)C2=CC(F)=CC=C2C1=O |o1:3|', {'pIC50 (SARS-CoV-2 Mpro)': 6.34, 'pIC50 (MERS-CoV Mpro)': 5.42})
# ('CC(C)C[C@H]1CN(C(=O)COS(=O)(=O)N2CCNCC2)CCN1CC1=CC=CC(Cl)=C1 |&1:4|', {'pIC50 (SARS-CoV-2 Mpro)': 6.92, 'pIC50 (MERS-CoV Mpro)': 4.25})
# ('CN1C[C@H](C(=O)NC2=CN=CC3=CC=CC=C23)C2=CC=CC=C2C1=O |o1:3|', {'pIC50 (SARS-CoV-2 Mpro)': 5.22, 'pIC50 (MERS-CoV Mpro)': 4.5})
# ('C=C(CN(C(=O)[C@H]1CN(CC(=O)NC)CC2=CC=C(Cl)C=C21)C1=CN=CC2=CC=CC=C12)C(=O)O |&1:6|', {'pIC50 (SARS-CoV-2 Mpro)': 4.88, 'pIC50 (MERS-CoV Mpro)': 4.68})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N1CCC[C@H]1C1=C(Cl)C=CC=C1Cl |&1:17|', {'pIC50 (SARS-CoV-2 Mpro)': 4.38, 'pIC50 (MERS-CoV Mpro)': 4.73})
# ('CN1C[C@H](C(=O)NC2=CN=CC3=CC=CC=C23)C2=CC=CC=C2C1=O |o1:3|', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.27})
# ('C[C@H]1CN(C2=CN=CC3=CC=CC=C23)C(=O)[C@]12CN1N=NC=C1C1=CC=C(Cl)C=C12', {'pIC50 (SARS-CoV-2 Mpro)': 4.11, 'pIC50 (MERS-CoV Mpro)': 4.38})
# ('N#CC1=CC=C(N(CC2=CC=CC=C2)C(=O)CC2=CN=CC3=CC=CC=C23)C=C1', {'pIC50 (SARS-CoV-2 Mpro)': 4.89, 'pIC50 (MERS-CoV Mpro)': 5.69})
# ('CN1C[C@H](C(=O)NC2=CN=CC3=CC=CC=C23)C2=CC(C(F)(F)F)=CC=C2C1=O |o1:3|', {'pIC50 (SARS-CoV-2 Mpro)': 4.75, 'pIC50 (MERS-CoV Mpro)': 4.32})
# ('CN1C[C@H](C(=O)NC2=CN=CC3=CC=CC=C23)C2=CC(C(F)(F)F)=CC=C2C1=O |o1:3|', {'pIC50 (SARS-CoV-2 Mpro)': 5.44, 'pIC50 (MERS-CoV Mpro)': 4.95})
# ('CN1C[C@]2(CCCN(C3=CN=CC4=CC=CC=C34)C2=O)C2=CC(Cl)=CC=C2C1=O |o1:3|', {'pIC50 (SARS-CoV-2 Mpro)': 5.98, 'pIC50 (MERS-CoV Mpro)': 4.79})
# ('CN1C[C@]2(CCCN(C3=CN=CC4=CC=CC=C34)C2=O)C2=CC(Cl)=CC=C2C1=O |o1:3|', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.12})
# ('C[C@H]1CN(C2=CN=CC3=CC=CC=C23)C(=O)[C@@]12CN1N=NC=C1C1=CC=C(Cl)C=C12', {'pIC50 (SARS-CoV-2 Mpro)': 6.18, 'pIC50 (MERS-CoV Mpro)': 5.16})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N1CC2=CC=CC=C2OCC12CC2', {'pIC50 (SARS-CoV-2 Mpro)': 4.45, 'pIC50 (MERS-CoV Mpro)': 4.68})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N1CCCC2=CC=CC=C21', {'pIC50 (SARS-CoV-2 Mpro)': 4.68, 'pIC50 (MERS-CoV Mpro)': 4.74})
# ('CN(C(=O)CC1=CN=CC2=CC=CC=C12)[C@H](C1=CC=C(Cl)C=C1)C1CC1 |&1:15|', {'pIC50 (SARS-CoV-2 Mpro)': 4.8, 'pIC50 (MERS-CoV Mpro)': 4.4})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N1CC[C@H]2CCCC[C@H]21 |&1:16,21|', {'pIC50 (SARS-CoV-2 Mpro)': 4.5, 'pIC50 (MERS-CoV Mpro)': 3.96})
# ('CC1=CC=C(F)C(CN(C)C(=O)CC2=CN=CC3=CC=CC=C23)=C1F', {'pIC50 (SARS-CoV-2 Mpro)': 4.24, 'pIC50 (MERS-CoV Mpro)': 4.73})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N1CCC2=CC=C(Cl)C=C2CC1', {'pIC50 (SARS-CoV-2 Mpro)': 5.43, 'pIC50 (MERS-CoV Mpro)': 3.9})
# ('CN(CC1=CC=CC(Cl)=C1)C(=O)CC1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': 5.23, 'pIC50 (MERS-CoV Mpro)': 4.44})
# ('CN(CCC1=CC=CC=C1Cl)C(=O)CC1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': 4.56, 'pIC50 (MERS-CoV Mpro)': 3.61})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N(CC1=CC=CS1)C1=CC=CC=C1', {'pIC50 (SARS-CoV-2 Mpro)': 5.0, 'pIC50 (MERS-CoV Mpro)': 5.26})
# ('COC1=CC=C(N(CC2=CC=CC=C2)C(=O)CC2=CN=CC3=CC=CC=C23)C=C1', {'pIC50 (SARS-CoV-2 Mpro)': 5.37, 'pIC50 (MERS-CoV Mpro)': 5.72})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N1CCC[C@H]2CCC(F)(F)C[C@H]21 |&1:17,24|', {'pIC50 (SARS-CoV-2 Mpro)': 4.46, 'pIC50 (MERS-CoV Mpro)': 4.42})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N(CC1=CC=CC(F)=C1)C1CC1', {'pIC50 (SARS-CoV-2 Mpro)': 5.52, 'pIC50 (MERS-CoV Mpro)': 4.76})
# ('CC1=NN(C)C(CN(C)C(=O)CC2=CN=CC3=CC=CC=C23)=C1', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.18})
# ('C[C@H]1[C@H]2CCCC[C@H]2CN1C(=O)CC1=CN=CC2=CC=CC=C12 |&1:1,&2:2,&3:7|', {'pIC50 (SARS-CoV-2 Mpro)': 5.02, 'pIC50 (MERS-CoV Mpro)': 4.3})
# ('O=C(CC1=CN=CC2=CC=CC=C12)NCC1=CC=CC(Cl)=C1', {'pIC50 (SARS-CoV-2 Mpro)': 5.25, 'pIC50 (MERS-CoV Mpro)': 4.08})
# ('C[C@H]1CC[C@H]2CCCN(C(=O)CC3=CN=CC4=CC=CC=C34)[C@H]2C1 |&1:1,&2:4,&3:22|', {'pIC50 (SARS-CoV-2 Mpro)': 4.92, 'pIC50 (MERS-CoV Mpro)': 4.27})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N1CC[C@H]2CCCC[C@H]2CC1 |&1:16,&2:21|', {'pIC50 (SARS-CoV-2 Mpro)': 5.88, 'pIC50 (MERS-CoV Mpro)': 4.75})
# ('CC1=CC=CC(CN(C(=O)CC2=CN=CC3=CC=CC=C23)C2CC2)=C1', {'pIC50 (SARS-CoV-2 Mpro)': 5.04, 'pIC50 (MERS-CoV Mpro)': 4.33})
# ('CCCN(CCC1=CC=CS1)C(=O)CC1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': 4.68, 'pIC50 (MERS-CoV Mpro)': 4.75})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N1CCCCCC2=CC=CC=C2C1', {'pIC50 (SARS-CoV-2 Mpro)': 5.79, 'pIC50 (MERS-CoV Mpro)': 5.36})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N1CCC[C@H]1C1=CC=C(Cl)C=C1 |&1:17|', {'pIC50 (SARS-CoV-2 Mpro)': 4.68, 'pIC50 (MERS-CoV Mpro)': 4.94})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N(CC1=CC=CC=C1)C1=CC=CC=C1', {'pIC50 (SARS-CoV-2 Mpro)': 5.11, 'pIC50 (MERS-CoV Mpro)': 5.36})
# ('CC(C)N(CC1=CC=CC(Cl)=C1)C(=O)CC1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': 5.82, 'pIC50 (MERS-CoV Mpro)': 4.62})
# ('CN1C[C@H](C(=O)NC2=CN=CC3=CC=CC=C23)C2=CC(C3CC3)=CC=C2C1=O |o1:3|', {'pIC50 (SARS-CoV-2 Mpro)': 5.55, 'pIC50 (MERS-CoV Mpro)': 5.89})
# ('CN1C[C@H](C(=O)NC2=CN=CC3=CC=CC=C23)C2=CC(C3CC3)=CC=C2C1=O |o1:3|', {'pIC50 (SARS-CoV-2 Mpro)': 4.09, 'pIC50 (MERS-CoV Mpro)': 4.31})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N(CC1=CC=C(F)C=C1)C1CCCCC1', {'pIC50 (SARS-CoV-2 Mpro)': 5.05, 'pIC50 (MERS-CoV Mpro)': 5.05})
# ('C[C@H](C1=CC=CC=C1)N(CC1=CC=CC=C1)C(=O)CC1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': 5.15, 'pIC50 (MERS-CoV Mpro)': 5.2})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N(CC1=CC=CC=C1)CC1=CC=C(F)C=C1', {'pIC50 (SARS-CoV-2 Mpro)': 5.0, 'pIC50 (MERS-CoV Mpro)': 5.02})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N(CC1=CC=CC=C1O)C1=CC=C(F)C=C1', {'pIC50 (SARS-CoV-2 Mpro)': 4.78, 'pIC50 (MERS-CoV Mpro)': 4.89})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N1CCC[C@H]1C1=C(F)C=CC(Cl)=C1F |&1:17|', {'pIC50 (SARS-CoV-2 Mpro)': 5.38, 'pIC50 (MERS-CoV Mpro)': 3.87})
# ('CN1C[C@]2(CCN(C3=CN=CC4=CC=CC=C34)C2=O)C2=CC(Cl)=CC=C2C1=O |o1:3|', {'pIC50 (SARS-CoV-2 Mpro)': 6.31, 'pIC50 (MERS-CoV Mpro)': 5.4})
# ('CN1C[C@]2(CCN(C3=CN=CC4=CC=CC=C34)C2=O)C2=CC(Cl)=CC=C2C1=O |o1:3|', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.28})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N(CC1=CC=C2NC=CC2=C1)CC1=CC=CS1', {'pIC50 (SARS-CoV-2 Mpro)': 4.97, 'pIC50 (MERS-CoV Mpro)': 5.24})
# ('CNC(=O)CN1C[C@@]2(C(=O)N(C3=CN=CC4=CC=CC=C34)C[C@@H]2CC2=CC=CC=C2)C2=CC(F)=CC=C2C1=O', {'pIC50 (SARS-CoV-2 Mpro)': 6.96, 'pIC50 (MERS-CoV Mpro)': 5.68})
# ('O=C(NC1=CC=CC=C1)OCC1=CC=CC=C1', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.1})
# ('N=C(N)NCCC1=CC=CC(B(O)O)=C1', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 6.61})
# ('N=C(N)NC1=CC=C(OC(=O)NC2=CC=CC=C2)C=C1', {'pIC50 (SARS-CoV-2 Mpro)': 5.68, 'pIC50 (MERS-CoV Mpro)': 4.49})
# ('O=C(CC1=CC(F)=C(F)C(F)=C1)NC1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': 6.33, 'pIC50 (MERS-CoV Mpro)': 3.58})
# ('N=C(N)NCCC1=CC=C(OC(=O)NC2=CC=CC=C2)C=C1', {'pIC50 (SARS-CoV-2 Mpro)': 4.8, 'pIC50 (MERS-CoV Mpro)': 4.27})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N1CC(F)(F)C[C@H]2CCCC[C@H]21 |&1:19,&2:24|', {'pIC50 (SARS-CoV-2 Mpro)': 4.03, 'pIC50 (MERS-CoV Mpro)': 4.85})
# ('CN1C[C@H](C(=O)NC2=CN=CC3=CC=CC=C23)C2=CC(C#N)=CC=C2C1=O |o1:3|', {'pIC50 (SARS-CoV-2 Mpro)': 6.08, 'pIC50 (MERS-CoV Mpro)': 5.04})
# ('CN1C[C@H](C(=O)NC2=CN=CC3=CC=CC=C23)C2=CC(C#N)=CC=C2C1=O |o1:3|', {'pIC50 (SARS-CoV-2 Mpro)': 4.92, 'pIC50 (MERS-CoV Mpro)': 4.15})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N1CCC2=CC=CC=C2C2=CC=CC=C21', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 3.97})
# ('N#CC1(N(C(=O)CC2=CN=CC3=CC=CC=C23)C2=CC=CC=C2)CCCCC1', {'pIC50 (SARS-CoV-2 Mpro)': 4.85, 'pIC50 (MERS-CoV Mpro)': 4.79})
# ('CC(C)(C#N)NC(=O)[C@H](CC1=CC=CC(Cl)=C1)C1=CN=CC2=CC=CC=C12 |&1:8|', {'pIC50 (SARS-CoV-2 Mpro)': 4.12, 'pIC50 (MERS-CoV Mpro)': 3.51})
# ('O=C1N(C2=CN=CC3=CC=CC=C23)CCC[C@]12CCOC1=CC=C(Cl)C=C12 |o1:16|', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.28})
# ('O=C1N(C2=CN=CC3=CC=CC=C23)CCC[C@]12CCOC1=CC=C(Cl)C=C12 |o1:16|', {'pIC50 (SARS-CoV-2 Mpro)': 6.53, 'pIC50 (MERS-CoV Mpro)': 5.12})
# ('CNC(=O)CN1C[C@@]2(C(=O)N(C3=CN=CC4=CC=CC=C34)C[C@@H]2C)C2=C(F)C=CC=C2C1=O', {'pIC50 (SARS-CoV-2 Mpro)': 4.38, 'pIC50 (MERS-CoV Mpro)': 4.27})
# ('COC1=CC=C2C=NC=C(CC(=O)N(CC3=CC=CC(Cl)=C3)C3=CC=C(N(C)C)C=N3)C2=C1', {'pIC50 (SARS-CoV-2 Mpro)': 6.69, 'pIC50 (MERS-CoV Mpro)': 5.69})
# ('CNC(=O)CN1C[C@]2(C(=O)N(C3=CN=CC4=CC=CC=C34)C3=CC=CC=C32)C2=CC(F)=CC=C2C1=O |&1:7|', {'pIC50 (SARS-CoV-2 Mpro)': 6.44, 'pIC50 (MERS-CoV Mpro)': 5.42})
# ('COC1=CC2=CN=CC(CC(=O)N(CC3=CC=CC(Cl)=C3)C3=CC=C(N(C)C)C=N3)=C2C=C1OC', {'pIC50 (SARS-CoV-2 Mpro)': 5.84, 'pIC50 (MERS-CoV Mpro)': 4.58})
# ('C=C(CN(C(=O)[C@H]1CN(CC(=O)NC)CC2=CC=C(Cl)C=C21)C1=CN=CC2=CC=CC=C12)C(=O)NC1=CC=CC=C1 |&1:6|', {'pIC50 (SARS-CoV-2 Mpro)': 7.1, 'pIC50 (MERS-CoV Mpro)': 4.77})
# ('N=C(N)NCC1=CC=C(OC(=O)NC2=CC=CC=C2)C=C1', {'pIC50 (SARS-CoV-2 Mpro)': 5.13, 'pIC50 (MERS-CoV Mpro)': 4.2})
# ...
# ('O=C1C2=CC=C(Cl)C=C2[C@@]2(CN1CC1=NNC=C1)C(=O)N(C1=CN=CC3=CC=CC=C13)C[C@@H]2CNC1=NN=CO1 |a:9,32|', {'pIC50 (SARS-CoV-2 Mpro)': 8.18, 'pIC50 (MERS-CoV Mpro)': 7.12})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N1CC[C@]2(CCCC3=CC=CC=C32)C1 |o1:16|', {'pIC50 (SARS-CoV-2 Mpro)': 5.35, 'pIC50 (MERS-CoV Mpro)': 3.55})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N1CC[C@]2(CCCC3=CC=CC=C32)C1 |o1:16|', {'pIC50 (SARS-CoV-2 Mpro)': 5.54, 'pIC50 (MERS-CoV Mpro)': 4.53})
# ('C[C@H]1CCCN(C(=O)CC2=CN=CC3=CC=CC=C23)CC1 |o1:1|', {'pIC50 (SARS-CoV-2 Mpro)': 5.79, 'pIC50 (MERS-CoV Mpro)': 5.22})
# ('C[C@H]1CCCN(C(=O)CC2=CN=CC3=CC=CC=C23)CC1 |o1:1|', {'pIC50 (SARS-CoV-2 Mpro)': 5.55, 'pIC50 (MERS-CoV Mpro)': 5.13})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N1C[C@H]2CCCCCC[C@@H]2C1 |o1:15,22|', {'pIC50 (SARS-CoV-2 Mpro)': 5.76, 'pIC50 (MERS-CoV Mpro)': 4.09})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N1C[C@H]2CCCCCC[C@@H]2C1 |o1:15,22|', {'pIC50 (SARS-CoV-2 Mpro)': 6.03, 'pIC50 (MERS-CoV Mpro)': 4.08})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N1CC[C@]2(CC=CCO2)C1 |o1:16|', {'pIC50 (SARS-CoV-2 Mpro)': 5.16, 'pIC50 (MERS-CoV Mpro)': 4.53})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N1CC[C@]2(CC=CCO2)C1 |o1:16|', {'pIC50 (SARS-CoV-2 Mpro)': 5.34, 'pIC50 (MERS-CoV Mpro)': 4.11})
# ('COC1=CC=CC=C1[C@@H]1C[C@H](C)CCN1C(=O)CC1=CN=CC2=CC=CC=C12 |o1:8,10|', {'pIC50 (SARS-CoV-2 Mpro)': 5.87, 'pIC50 (MERS-CoV Mpro)': 6.22})
# ('COC1=CC=CC=C1[C@@H]1C[C@H](C)CCN1C(=O)CC1=CN=CC2=CC=CC=C12 |o1:8,10|', {'pIC50 (SARS-CoV-2 Mpro)': 6.19, 'pIC50 (MERS-CoV Mpro)': 6.16})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N1CC[C@H]2CCC(F)(F)C[C@H]2C1 |o1:16,23|', {'pIC50 (SARS-CoV-2 Mpro)': 6.28, 'pIC50 (MERS-CoV Mpro)': 5.23})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N1CC[C@H]2CCC(F)(F)C[C@H]2C1 |o1:16,23|', {'pIC50 (SARS-CoV-2 Mpro)': 5.33, 'pIC50 (MERS-CoV Mpro)': 4.08})
# ('C[C@H]1CC(F)(F)CCN1C(=O)CC1=CN=CC2=CC=CC=C12 |o1:1|', {'pIC50 (SARS-CoV-2 Mpro)': 5.49, 'pIC50 (MERS-CoV Mpro)': 5.77})
# ('C[C@H]1CC(F)(F)CCN1C(=O)CC1=CN=CC2=CC=CC=C12 |o1:1|', {'pIC50 (SARS-CoV-2 Mpro)': 5.29, 'pIC50 (MERS-CoV Mpro)': 5.59})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N1CC[C@H](C2=CC=CC(F)=C2)C1 |o1:16|', {'pIC50 (SARS-CoV-2 Mpro)': 5.03, 'pIC50 (MERS-CoV Mpro)': 4.85})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N1CC[C@H](C2=CC=CC(F)=C2)C1 |o1:16|', {'pIC50 (SARS-CoV-2 Mpro)': 5.28, 'pIC50 (MERS-CoV Mpro)': 4.06})
# ('CO[C@]1(C(F)(F)F)CCN(C(=O)CC2=CN=CC3=CC=CC=C23)C1 |o1:2|', {'pIC50 (SARS-CoV-2 Mpro)': 5.23, 'pIC50 (MERS-CoV Mpro)': 4.7})
# ('CO[C@]1(C(F)(F)F)CCN(C(=O)CC2=CN=CC3=CC=CC=C23)C1 |o1:2|', {'pIC50 (SARS-CoV-2 Mpro)': 5.15, 'pIC50 (MERS-CoV Mpro)': 4.48})
# ('C[C@H]1CCN(C(=O)CC2=CN=CC3=CC=CC=C23)[C@@H](C2CCOCC2)C1 |o1:1,18|', {'pIC50 (SARS-CoV-2 Mpro)': 5.15, 'pIC50 (MERS-CoV Mpro)': 4.26})
# ('C[C@H]1CCN(C(=O)CC2=CN=CC3=CC=CC=C23)[C@@H](C2CCOCC2)C1 |o1:1,18|', {'pIC50 (SARS-CoV-2 Mpro)': 5.34, 'pIC50 (MERS-CoV Mpro)': 5.27})
# ('CC[C@H]1C[C@@H](C(F)(F)F)CCN1C(=O)CC1=CN=CC2=CC=CC=C12 |o1:2,4|', {'pIC50 (SARS-CoV-2 Mpro)': 6.13, 'pIC50 (MERS-CoV Mpro)': 5.49})
# ('CC[C@H]1C[C@@H](C(F)(F)F)CCN1C(=O)CC1=CN=CC2=CC=CC=C12 |o1:2,4|', {'pIC50 (SARS-CoV-2 Mpro)': 5.92, 'pIC50 (MERS-CoV Mpro)': 5.87})
# ('COC1=CC=CC(C[C@H]2CCCN2C(=O)CC2=CN=CC3=CC=CC=C23)=C1 |o1:8|', {'pIC50 (SARS-CoV-2 Mpro)': 5.28, 'pIC50 (MERS-CoV Mpro)': 4.05})
# ('COC1=CC=CC(C[C@H]2CCCN2C(=O)CC2=CN=CC3=CC=CC=C23)=C1 |o1:8|', {'pIC50 (SARS-CoV-2 Mpro)': 5.36, 'pIC50 (MERS-CoV Mpro)': 4.57})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N1[C@H]2C=CC[C@@H]1CCC2 |o1:14,18|', {'pIC50 (SARS-CoV-2 Mpro)': 5.45, 'pIC50 (MERS-CoV Mpro)': 4.83})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N1[C@H]2C=CC[C@@H]1CCC2 |o1:14,18|', {'pIC50 (SARS-CoV-2 Mpro)': 4.95, 'pIC50 (MERS-CoV Mpro)': 4.61})
# ('CC(C)[C@]1(C#N)CCN(C(=O)CC2=CN=CC3=CC=CC=C23)C1 |o1:3|', {'pIC50 (SARS-CoV-2 Mpro)': 5.1, 'pIC50 (MERS-CoV Mpro)': 4.46})
# ('CC(C)[C@]1(C#N)CCN(C(=O)CC2=CN=CC3=CC=CC=C23)C1 |o1:3|', {'pIC50 (SARS-CoV-2 Mpro)': 6.23, 'pIC50 (MERS-CoV Mpro)': 4.42})
# ('CC1=CSC2=C1CN(C(=O)CC1=CN=CC3=CC=CC=C13)CC2', {'pIC50 (SARS-CoV-2 Mpro)': 6.48, 'pIC50 (MERS-CoV Mpro)': 4.99})
# ('CC1=NN=C(NC[C@H]2CN(C3=CN=CC4=CC=CC=C34)C(=O)[C@@]23CN(CC2=NNC=C2)C(=O)C2=CC=C(Cl)C=C23)O1 |a:7,22|', {'pIC50 (SARS-CoV-2 Mpro)': 7.68, 'pIC50 (MERS-CoV Mpro)': 6.93})
# ('CC1=CC2=C(CCN(C(=O)CC3=CN=CC4=CC=CC=C34)C2)S1', {'pIC50 (SARS-CoV-2 Mpro)': 5.38, 'pIC50 (MERS-CoV Mpro)': 3.98})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N1C[C@H]2CC[C@H]2[C@H]1C1=CC=CC=C1 |o1:15,18,19|', {'pIC50 (SARS-CoV-2 Mpro)': 4.75, 'pIC50 (MERS-CoV Mpro)': 4.58})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N1C[C@H]2CC[C@H]2[C@H]1C1=CC=CC=C1 |o1:15,18,19|', {'pIC50 (SARS-CoV-2 Mpro)': 5.44, 'pIC50 (MERS-CoV Mpro)': 5.02})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N1CCC[C@H]1C1=CC=CC(F)=C1F |o1:17|', {'pIC50 (SARS-CoV-2 Mpro)': 4.26, 'pIC50 (MERS-CoV Mpro)': 4.43})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N1CCC[C@H]1C1=CC=CC(F)=C1F |o1:17|', {'pIC50 (SARS-CoV-2 Mpro)': 5.61, 'pIC50 (MERS-CoV Mpro)': 4.09})
# ('O=C(CC1=CC=CN=C1)N1CCC2=C(C=CS2)C1', {'pIC50 (SARS-CoV-2 Mpro)': 4.47, 'pIC50 (MERS-CoV Mpro)': 4.4})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N1CC[C@H]2CC[C@H]1C2 |&1:16,&2:19|', {'pIC50 (SARS-CoV-2 Mpro)': 4.67, 'pIC50 (MERS-CoV Mpro)': 4.81})
# ('C[C@H]1CCN(C(=O)CC2=CN=CC3=CC=CC=C23)[C@H]2C(=O)NC[C@@H]12 |o1:1,18,23|', {'pIC50 (SARS-CoV-2 Mpro)': 5.49, 'pIC50 (MERS-CoV Mpro)': 4.41})
# ('C[C@H]1CCN(C(=O)CC2=CN=CC3=CC=CC=C23)[C@H]2C(=O)NC[C@@H]12 |o1:1,18,23|', {'pIC50 (SARS-CoV-2 Mpro)': 5.21, 'pIC50 (MERS-CoV Mpro)': 4.65})
# ('C[C@H]1CN(C(=O)CC2=CN=CC3=CC=CC=C23)CCC12COC2 |&1:1|', {'pIC50 (SARS-CoV-2 Mpro)': 4.03, 'pIC50 (MERS-CoV Mpro)': 4.29})
# ('C[C@H]1C[C@H]2C[C@@H]1CN2C(=O)CC1=CN=CC2=CC=CC=C12 |&1:1,3,5|', {'pIC50 (SARS-CoV-2 Mpro)': 4.98, 'pIC50 (MERS-CoV Mpro)': 4.78})
# ('C[C@H]1CCN(C(=O)CC2=CN=CC3=CC=CC=C23)C[C@H]1O |&1:1,19|', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.93})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N1CCC2(O)CC1C2', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.22})
# ('C[C@H]1CCN(C(=O)CC2=CN=CC3=CC=CC=C23)C[C@@H]1O |&1:1,19|', {'pIC50 (SARS-CoV-2 Mpro)': 4.6, 'pIC50 (MERS-CoV Mpro)': 4.06})
# ('CCC1=CC=C([C@H]2C[C@H](C)CCN2C(=O)CC2=CN=CC3=CC=CC=C23)O1 |o1:6,8|', {'pIC50 (SARS-CoV-2 Mpro)': 5.93, 'pIC50 (MERS-CoV Mpro)': 5.22})
# ('C[C@@H](O)C1CCN(C(=O)CC2=CN=CC3=CC=CC=C23)CC1 |a:1|', {'pIC50 (SARS-CoV-2 Mpro)': 4.32, 'pIC50 (MERS-CoV Mpro)': 4.35})
# ('N#CC1CCN(C(=O)CC2=CN=CC3=CC=CC=C23)CC1', {'pIC50 (SARS-CoV-2 Mpro)': 4.74, 'pIC50 (MERS-CoV Mpro)': 4.01})
# ('CN1CCN(C(=O)CC2=CN=CC3=CC=CC=C23)CC1', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.34})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N1CC[C@H](OC(F)(F)F)C1 |o1:16|', {'pIC50 (SARS-CoV-2 Mpro)': 5.18, 'pIC50 (MERS-CoV Mpro)': 4.5})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N1CC[C@H](OC(F)(F)F)C1 |o1:16|', {'pIC50 (SARS-CoV-2 Mpro)': 5.99, 'pIC50 (MERS-CoV Mpro)': 4.92})
# ('C[C@H]1CN(C)CCN1C(=O)CC1=CN=CC2=CC=CC=C12 |&1:1|', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.92})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N1CC[C@H]2C[C@@H]1C2 |a:16,18|', {'pIC50 (SARS-CoV-2 Mpro)': 4.39, 'pIC50 (MERS-CoV Mpro)': 4.48})
# ('C[C@H]1C[C@H]2CC[C@@H](C1)N2C(=O)CC1=CN=CC2=CC=CC=C12 |a:1,3,6|', {'pIC50 (SARS-CoV-2 Mpro)': 5.38, 'pIC50 (MERS-CoV Mpro)': 4.82})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N1C[C@H]2C[C@H]2C1 |&1:15,&2:17|', {'pIC50 (SARS-CoV-2 Mpro)': 4.19, 'pIC50 (MERS-CoV Mpro)': 4.23})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N1CC[C@H]2COC[C@H]1C2 |&1:16,&2:20|', {'pIC50 (SARS-CoV-2 Mpro)': 4.14, 'pIC50 (MERS-CoV Mpro)': 4.07})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N1CC[C@H]2CCC[C@H]1C2 |&1:16,&2:20|', {'pIC50 (SARS-CoV-2 Mpro)': 4.97, 'pIC50 (MERS-CoV Mpro)': 5.06})
# ('CC1(O)CCN(C(=O)CC2=CN=CC3=CC=CC=C23)CC1', {'pIC50 (SARS-CoV-2 Mpro)': 4.62, 'pIC50 (MERS-CoV Mpro)': 4.38})
# ('CO[C@@H]1CN(C(=O)CC2=CN=CC3=CC=CC=C23)CC[C@H]1C |&1:2,20|', {'pIC50 (SARS-CoV-2 Mpro)': 5.07, 'pIC50 (MERS-CoV Mpro)': 4.45})
# ('CC1(C)[C@H]2CN(C(=O)CC3=CN=CC4=CC=CC=C34)C[C@H]21 |&1:3,&2:20|', {'pIC50 (SARS-CoV-2 Mpro)': 5.46, 'pIC50 (MERS-CoV Mpro)': 5.2})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N1C[C@H]2C[C@@H]1[C@@H]1C[C@H]21 |&1:15,17,18,20|', {'pIC50 (SARS-CoV-2 Mpro)': 4.44, 'pIC50 (MERS-CoV Mpro)': 4.06})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N1CCC(CF)CC1', {'pIC50 (SARS-CoV-2 Mpro)': 5.63, 'pIC50 (MERS-CoV Mpro)': 5.16})
# ('COCC1(C)CCN(C(=O)CC2=CN=CC3=CC=CC=C23)CC1', {'pIC50 (SARS-CoV-2 Mpro)': 4.93, 'pIC50 (MERS-CoV Mpro)': 4.1})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N1CC[C@H]2C[C@H](O)C[C@H]2C1 |&1:16,21,&2:18|', {'pIC50 (SARS-CoV-2 Mpro)': 4.16, 'pIC50 (MERS-CoV Mpro)': 4.87})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N1CCC2=C(C=CS2)[C@H]1C1CC1 |&1:21|', {'pIC50 (SARS-CoV-2 Mpro)': 6.49, 'pIC50 (MERS-CoV Mpro)': 5.1})
# ('CC1=CC=C2CN(C(=O)CC3=CN=CC4=CC=CC=C34)CCC2=N1', {'pIC50 (SARS-CoV-2 Mpro)': 4.44, 'pIC50 (MERS-CoV Mpro)': 4.35})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N1C[C@H](O)C2CC1C2 |&1:15|', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.31})
# ('CC(C)[C@H]1C2=C(CCN1C(=O)CC1=CN=CC3=CC=CC=C13)SC=C2 |&1:3|', {'pIC50 (SARS-CoV-2 Mpro)': 6.86, 'pIC50 (MERS-CoV Mpro)': 5.53})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N1CC[C@H]2[C@H](F)[C@H]2C1 |&1:16,&2:17,&3:19|', {'pIC50 (SARS-CoV-2 Mpro)': 5.2, 'pIC50 (MERS-CoV Mpro)': 5.15})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N1CC[C@@]2(O)C[C@H]2C1 |&1:16,19|', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.61})
# ('O=C1C2=CC=C(Cl)C=C2[C@@]2(CN1CC1=NNC=C1)C(=O)N(C1=CN=CC3=CC=CC=C13)C[C@@H]2CNC1=NN=C(C(F)(F)F)S1 |a:9,32|', {'pIC50 (SARS-CoV-2 Mpro)': 7.34, 'pIC50 (MERS-CoV Mpro)': 7.22})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N1CCC2=NC=C(C(F)(F)F)C=C2C1', {'pIC50 (SARS-CoV-2 Mpro)': 4.4, 'pIC50 (MERS-CoV Mpro)': 4.24})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N1CCC2=NC(C(F)(F)F)=CC=C2C1', {'pIC50 (SARS-CoV-2 Mpro)': 4.13, 'pIC50 (MERS-CoV Mpro)': 4.26})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N1CCC2=NC=CC=C2C1', {'pIC50 (SARS-CoV-2 Mpro)': 4.26, 'pIC50 (MERS-CoV Mpro)': 4.28})
# ('C[C@H]1CC2=C(C=CS2)CN1C(=O)CC1=CN=CC2=CC=CC=C12 |&1:1|', {'pIC50 (SARS-CoV-2 Mpro)': 6.48, 'pIC50 (MERS-CoV Mpro)': 5.21})
# ('C[C@H]1C2=CC=CN=C2CCN1C(=O)CC1=CN=CC2=CC=CC=C12 |&1:1|', {'pIC50 (SARS-CoV-2 Mpro)': 4.34, 'pIC50 (MERS-CoV Mpro)': 4.28})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N1CCC2=NC=C(O)C=C2C1', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.24})
# ('CC1=CN=C2CCN(C(=O)CC3=CN=CC4=CC=CC=C34)CC2=C1', {'pIC50 (SARS-CoV-2 Mpro)': 5.03, 'pIC50 (MERS-CoV Mpro)': 4.76})
# ('C[C@H]1CN(C(=O)CC2=CN=CC3=CC=CC=C23)CC2=C1SC=C2 |&1:1|', {'pIC50 (SARS-CoV-2 Mpro)': 5.7, 'pIC50 (MERS-CoV Mpro)': 4.48})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N1CCC2=C(C=CS2)[C@H]1C1=CC=CC=C1 |&1:21|', {'pIC50 (SARS-CoV-2 Mpro)': 6.88, 'pIC50 (MERS-CoV Mpro)': 5.56})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N1CCC(CC(F)(F)F)CC1', {'pIC50 (SARS-CoV-2 Mpro)': 5.69, 'pIC50 (MERS-CoV Mpro)': 4.41})
# ('CC(C)[C@H]1C2=C(CCN1C(=O)CC1=CN=CC3=CC=CC=C13)SC=C2 |o1:3|', {'pIC50 (SARS-CoV-2 Mpro)': 5.49, 'pIC50 (MERS-CoV Mpro)': 4.6})
# ('COC[C@H]1C2=C(CCN1C(=O)CC1=CN=CC3=CC=CC=C13)SC=C2 |&1:3|', {'pIC50 (SARS-CoV-2 Mpro)': 6.3, 'pIC50 (MERS-CoV Mpro)': 5.23})
# ('O=C(COS(=O)(=O)NCC1=CC=CC=C1)N1CCN(CC2=CC=CC(Cl)=C2)[C@H]2CS(=O)(=O)C[C@H]21 |&1:27,33|', {'pIC50 (SARS-CoV-2 Mpro)': 5.55, 'pIC50 (MERS-CoV Mpro)': 5.1})
# ('C[C@H]1CC2=C(C=CS2)CN1C(=O)CC1=CN=CC2=CC=CC=C12 |o1:1|', {'pIC50 (SARS-CoV-2 Mpro)': 5.16, 'pIC50 (MERS-CoV Mpro)': 4.51})
# ('C[C@H]1CC2=C(C=CS2)CN1C(=O)CC1=CN=CC2=CC=CC=C12 |o1:1|', {'pIC50 (SARS-CoV-2 Mpro)': 6.7, 'pIC50 (MERS-CoV Mpro)': 5.29})
# ('C[C@H](C(=O)N1CCC2=C(C=CS2)C1)C1=CN=CC2=CC=CC=C12 |&1:1|', {'pIC50 (SARS-CoV-2 Mpro)': 4.09, 'pIC50 (MERS-CoV Mpro)': 4.27})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N1CCC2=NC=C(Cl)C=C2C1', {'pIC50 (SARS-CoV-2 Mpro)': 4.48, 'pIC50 (MERS-CoV Mpro)': 4.29})
# ('CNC(=O)C[C@@H]1CCCN(C(=O)CC2=CN=CC3=CC=CC=C23)C1 |a:5|', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.25})
# ('CC(C)(F)C1CCN(C(=O)CC2=CN=CC3=CC=CC=C23)CC1', {'pIC50 (SARS-CoV-2 Mpro)': 6.02, 'pIC50 (MERS-CoV Mpro)': 4.6})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N1CCC[C@@H](C(F)(F)F)C1 |a:17|', {'pIC50 (SARS-CoV-2 Mpro)': 4.74, 'pIC50 (MERS-CoV Mpro)': 4.0})
# ('C[C@H]1CCN(C(=O)CC2=CN=CC3=CC=CC=C23)C[C@H]1C |o1:1,19|', {'pIC50 (SARS-CoV-2 Mpro)': 5.26, 'pIC50 (MERS-CoV Mpro)': 4.88})
# ('C[C@H]1CCN(C(=O)CC2=CN=CC3=CC=CC=C23)C[C@H]1C |o1:1,19|', {'pIC50 (SARS-CoV-2 Mpro)': 4.9, 'pIC50 (MERS-CoV Mpro)': 4.57})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N1CCC[C@H](C(F)(F)F)CC1 |&1:17|', {'pIC50 (SARS-CoV-2 Mpro)': 6.33, 'pIC50 (MERS-CoV Mpro)': 5.59})
# ('C[C@H]1CN(C(=O)CC2=CN=CC3=CC=CC=C23)CC2=C1SC=C2 |o1:1|', {'pIC50 (SARS-CoV-2 Mpro)': 5.34, 'pIC50 (MERS-CoV Mpro)': 4.21})
# ('C[C@H]1CN(C(=O)CC2=CN=CC3=CC=CC=C23)CC2=C1SC=C2 |o1:1|', {'pIC50 (SARS-CoV-2 Mpro)': 5.92, 'pIC50 (MERS-CoV Mpro)': 4.6})
# ('C#CC1(C)CCN(C(=O)CC2=CN=CC3=CC=CC=C23)CC1', {'pIC50 (SARS-CoV-2 Mpro)': 5.33, 'pIC50 (MERS-CoV Mpro)': 4.99})
# ('N#CC[C@@H]1CCCN(C(=O)CC2=CN=CC3=CC=CC=C23)C1 |a:3|', {'pIC50 (SARS-CoV-2 Mpro)': 4.34, 'pIC50 (MERS-CoV Mpro)': 4.3})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N1CCC[C@H](CCO)C1 |a:17|', {'pIC50 (SARS-CoV-2 Mpro)': 4.1, 'pIC50 (MERS-CoV Mpro)': 4.26})
# ('CCC1(C)CCN(C(=O)CC2=CN=CC3=CC=CC=C23)CC1', {'pIC50 (SARS-CoV-2 Mpro)': 6.13, 'pIC50 (MERS-CoV Mpro)': 5.3})
# ('O=C(CN(CC1=CC=CC(Cl)=C1)C(=O)CC1=CN=CC2=CC=CC=C12)N1CCCC1', {'pIC50 (SARS-CoV-2 Mpro)': 5.75, 'pIC50 (MERS-CoV Mpro)': 4.87})
# ('CNC(=O)CN(CC1=CC=CC(Cl)=C1)C(=O)CC1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': 5.36, 'pIC50 (MERS-CoV Mpro)': 4.64})
# ('C[C@H]1CCN(C(=O)CC2=CN=CC3=CC=CC=C23)C[C@@H]1C |o1:1,19|', {'pIC50 (SARS-CoV-2 Mpro)': 4.97, 'pIC50 (MERS-CoV Mpro)': 4.61})
# ('C[C@H]1CCN(C(=O)CC2=CN=CC3=CC=CC=C23)C[C@@H]1C |o1:1,19|', {'pIC50 (SARS-CoV-2 Mpro)': 6.17, 'pIC50 (MERS-CoV Mpro)': 5.19})
# ('CC[C@@H]1C[C@H](C)CCN1C(=O)CC1=CN=CC2=CC=CC=C12 |&1:2,4|', {'pIC50 (SARS-CoV-2 Mpro)': 5.64, 'pIC50 (MERS-CoV Mpro)': 5.59})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N1CCC[C@H](C(F)(F)F)C1 |a:17|', {'pIC50 (SARS-CoV-2 Mpro)': 5.43, 'pIC50 (MERS-CoV Mpro)': 4.62})
# ('CO[C@H]1C[C@H](O)CN(C(=O)CC2=CN=CC3=CC=CC=C23)C1 |a:2,4|', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.17})
# ('NC(=O)[C@H]1CCCN(C(=O)CC2=CN=CC3=CC=CC=C23)C1 |a:3|', {'pIC50 (SARS-CoV-2 Mpro)': 4.06, 'pIC50 (MERS-CoV Mpro)': 4.24})
# ('CNC(=O)C[C@H]1CCCCN1C(=O)CC1=CN=CC2=CC=CC=C12 |a:5|', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.9})
# ('CC1(C(F)(F)F)CCN(C(=O)CC2=CN=CC3=CC=CC=C23)CC1', {'pIC50 (SARS-CoV-2 Mpro)': 6.11, 'pIC50 (MERS-CoV Mpro)': 5.14})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N1CCC2=C(C=CS2)[C@H]1C1CC1 |o1:21|', {'pIC50 (SARS-CoV-2 Mpro)': 5.32, 'pIC50 (MERS-CoV Mpro)': 4.68})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N1CCC2=C(C=CS2)[C@H]1C1CC1 |o1:21|', {'pIC50 (SARS-CoV-2 Mpro)': 6.73, 'pIC50 (MERS-CoV Mpro)': 5.41})
# ('CO[C@@H]1C[C@H](O)CN(C(=O)CC2=CN=CC3=CC=CC=C23)C1 |a:2,4|', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.2})
# ('NC(=O)CN(CC1=CC=CC(Cl)=C1)C(=O)CC1=CN=CC2=CC=CC=C12', {'pIC50 (SARS-CoV-2 Mpro)': 5.48, 'pIC50 (MERS-CoV Mpro)': 4.74})
# ('CC(C)CC1CCN(C(=O)CC2=CN=CC3=CC=CC=C23)CC1', {'pIC50 (SARS-CoV-2 Mpro)': 5.31, 'pIC50 (MERS-CoV Mpro)': 4.46})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N1CCC([C@H]2CCOC2)CC1 |o1:17|', {'pIC50 (SARS-CoV-2 Mpro)': 4.57, 'pIC50 (MERS-CoV Mpro)': 4.25})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N1CCC([C@H]2CCOC2)CC1 |o1:17|', {'pIC50 (SARS-CoV-2 Mpro)': 4.68, 'pIC50 (MERS-CoV Mpro)': 4.27})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N1CCCC2(CC2)C1', {'pIC50 (SARS-CoV-2 Mpro)': 4.41, 'pIC50 (MERS-CoV Mpro)': 4.11})
# ('CC(=O)N[C@@H]1CCCN(C(=O)CC2=CN=CC3=CC=CC=C23)C1 |a:4|', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.24})
# ('NC(=O)O[C@H]1CCCN(C(=O)CC2=CN=CC3=CC=CC=C23)C1 |a:4|', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.26})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N1CCC[C@@H](CCO)C1 |a:17|', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.27})
# ('CNS(=O)(=O)OCC(=O)N1CCN(CC2=CC=CC(Cl)=C2)[C@H]2CS(=O)(=O)C[C@H]21 |&1:21,27|', {'pIC50 (SARS-CoV-2 Mpro)': 6.38, 'pIC50 (MERS-CoV Mpro)': 5.57})
# ('O=C(CC1=CN=CC2=CC=CC=C12)N1CC[C@@H]2CCCC[C@H]2C1 |a:16,21|', {'pIC50 (SARS-CoV-2 Mpro)': 6.09, 'pIC50 (MERS-CoV Mpro)': 4.6})
# ('CNC(=O)[C@H]1CCCN(C(=O)CC2=CN=CC3=CC=CC=C23)C1 |a:4|', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.22})
# ('C[C@H]1CCCN(C(=O)CC2=CN=CC3=CC=CC=C23)[C@H]1C |o1:1,19|', {'pIC50 (SARS-CoV-2 Mpro)': 5.06, 'pIC50 (MERS-CoV Mpro)': 4.4})
# ('O=C(O)C[C@H]1CCCN(C(=O)CC2=CN=CC3=CC=CC=C23)C1 |a:4|', {'pIC50 (SARS-CoV-2 Mpro)': nan, 'pIC50 (MERS-CoV Mpro)': 4.22})

# %%
import pandas as pd
import numpy as np

# Create empty lists to store the data
smiles = []
pIC50_MERS = []
pIC50_SARS = []

# Iterate through your dataset
for i in range(len(train)):
    item = train[i]
    # Extract SMILES string (first element of the tuple)
    smiles.append(item[0])
    # Extract pIC50 values (second element of the tuple is a dictionary)
    pIC50_MERS.append(item[1]['pIC50 (MERS-CoV Mpro)'])
    pIC50_SARS.append(item[1]['pIC50 (SARS-CoV-2 Mpro)'])

# Create the DataFrame
df = pd.DataFrame({
    'SMILES': smiles,
    'pIC50_MERS': pIC50_MERS,
    'pIC50_SARS': pIC50_SARS
})

# Display the first few rows of the DataFrame
print(df.head())
# Out:
#                                               SMILES  pIC50_MERS  pIC50_SARS
# 0  COC[C@]1(C)C(=O)N(C2=CN=CC3=CC=CC=C23)C(=O)N1C...        4.19         NaN
# 1  C=C(CN1CCC2=C(C=C(Cl)C=C2)C1C(=O)NC1=CN=CC2=CC...        4.92        5.29
# 2  CNC(=O)CN1C[C@]2(C[C@H](C)N(C3=CN=CC=C3C3CC3)C...        4.73         NaN
# 3  C=C(CN1CCC2=C(C=C(Cl)C=C2)C1C(=O)NC1=CN=CC2=CC...        4.90        6.11
# 4  C=C(CN1CCC2=C(C=C(Cl)C=C2)C1C(=O)NC1=CN=CC2=CC...        4.81        5.62

# %%
mpro_df = df
mpro_df
# Out:
#                                                  SMILES  pIC50_MERS  \
# 0     COC[C@]1(C)C(=O)N(C2=CN=CC3=CC=CC=C23)C(=O)N1C...        4.19
# 1     C=C(CN1CCC2=C(C=C(Cl)C=C2)C1C(=O)NC1=CN=CC2=CC...        4.92
# 2     CNC(=O)CN1C[C@]2(C[C@H](C)N(C3=CN=CC=C3C3CC3)C...        4.73
# 3     C=C(CN1CCC2=C(C=C(Cl)C=C2)C1C(=O)NC1=CN=CC2=CC...        4.90
# 4     C=C(CN1CCC2=C(C=C(Cl)C=C2)C1C(=O)NC1=CN=CC2=CC...        4.81
# ...                                                 ...         ...
# 1026  CNS(=O)(=O)OCC(=O)N1CCN(CC2=CC=CC(Cl)=C2)[C@H]...        5.57
# 1027  O=C(CC1=CN=CC2=CC=CC=C12)N1CC[C@@H]2CCCC[C@H]2...        4.60
# 1028  CNC(=O)[C@H]1CCCN(C(=O)CC2=CN=CC3=CC=CC=C23)C1...        4.22
# 1029  C[C@H]1CCCN(C(=O)CC2=CN=CC3=CC=CC=C23)[C@H]1C ...        4.40
# 1030  O=C(O)C[C@H]1CCCN(C(=O)CC2=CN=CC3=CC=CC=C23)C1...        4.22
#
#       pIC50_SARS
# 0            NaN
# 1           5.29
# 2            NaN
# 3           6.11
# 4           5.62
# ...          ...
# 1026        6.38
# 1027        6.09
# 1028         NaN
# 1029        5.06
# 1030         NaN
#
# [1031 rows x 3 columns]

# %%
# drop all NaN values
mpro_df = mpro_df.dropna()
mpro_df
# Out:
#                                                  SMILES  pIC50_MERS  \
# 1     C=C(CN1CCC2=C(C=C(Cl)C=C2)C1C(=O)NC1=CN=CC2=CC...        4.92
# 3     C=C(CN1CCC2=C(C=C(Cl)C=C2)C1C(=O)NC1=CN=CC2=CC...        4.90
# 4     C=C(CN1CCC2=C(C=C(Cl)C=C2)C1C(=O)NC1=CN=CC2=CC...        4.81
# 5     C=C(CN(C(=O)C1CCOC2=C1C=C(Cl)C=C2)C1=CN=CC2=CC...        4.88
# 6     C=C(CN(C(=O)C1CCOC2=C1C=C(Cl)C=C2)C1=CN=CC2=CC...        4.81
# ...                                                 ...         ...
# 1021  O=C(CC1=CN=CC2=CC=CC=C12)N1CCC([C@H]2CCOC2)CC1...        4.27
# 1022            O=C(CC1=CN=CC2=CC=CC=C12)N1CCCC2(CC2)C1        4.11
# 1026  CNS(=O)(=O)OCC(=O)N1CCN(CC2=CC=CC(Cl)=C2)[C@H]...        5.57
# 1027  O=C(CC1=CN=CC2=CC=CC=C12)N1CC[C@@H]2CCCC[C@H]2...        4.60
# 1029  C[C@H]1CCCN(C(=O)CC2=CN=CC3=CC=CC=C23)[C@H]1C ...        4.40
#
#       pIC50_SARS
# 1           5.29
# 3           6.11
# 4           5.62
# 5           6.45
# 6           5.56
# ...          ...
# 1021        4.68
# 1022        4.41
# 1026        6.38
# 1027        6.09
# 1029        5.06
#
# [712 rows x 3 columns]

# %%
X_train = mpro_df['SMILES']
Y_sars = mpro_df['pIC50_SARS']
Y_mers = mpro_df['pIC50_MERS']

# %%
X_train = np.array([dm.to_fp(dm.to_mol(smi)) for smi in mpro_df['SMILES']])
X_train
len(X_train), len(Y_sars), len(Y_mers)
# Out:
# (712, 712, 712)

# %%
X_test = np.array([dm.to_fp(dm.to_mol(smi)) for smi in test.X])
len(X_test)
# Out:
# 297

# %%
y_pred = {}

# %%
X_train = torch.tensor(X_train, dtype=torch.uint8)
Y_sars = torch.tensor(Y_sars.to_numpy(), dtype=torch.float32)
Y_mers = torch.tensor(Y_mers.to_numpy(), dtype=torch.float32)

# %%
X_test = torch.tensor(X_test, dtype=torch.uint8)

# %%
Y_sars.dtype
# Out:
# torch.float32

# %%
X_train.dtype
# Out:
# torch.uint8

# %%
class TanimotoKernel(gpytorch.kernels.Kernel):
    """
    A custom kernel implementing the Tanimoto similarity for GPyTorch models.

    The Tanimoto kernel is particularly useful for binary data, such as molecular fingerprints.
    It computes the similarity between two binary vectors using the Tanimoto coefficient.

    Attributes:
    -----------
    raw_lengthscale : torch.nn.Parameter
        A parameter for the kernel's lengthscale, initialized to zero.

    Methods:
    --------
    forward(x1, x2, diag=False, **params)
        Compute the Tanimoto similarity between two sets of inputs.

    Note:
    -----
    This kernel is suitable for use with binary feature vectors, such as ECFP fingerprints.
    """

    def __init__(self, **kwargs):
        """
        Initialize the TanimotoKernel.

        Parameters:
        -----------
        **kwargs : dict
            Additional keyword arguments to be passed to the parent Kernel class.
        """
        super(TanimotoKernel, self).__init__(**kwargs)
        self.register_parameter(name="raw_lengthscale", parameter=torch.nn.Parameter(torch.zeros(1)))

    def forward(self, x1, x2, diag=False, **params):
        """
        Compute the Tanimoto similarity between two sets of inputs.

        Parameters:
        -----------
        x1 : torch.Tensor
            First set of input vectors.
        x2 : torch.Tensor
            Second set of input vectors.
        diag : bool, optional
            If True, return only the diagonal of the covariance matrix (default is False).
        **params : dict
            Additional parameters for the computation.

        Returns:
        --------
        torch.Tensor
            The computed Tanimoto similarity matrix or its diagonal.
        """
        if diag:
            return self.covar_dist(x1, x2, diag=True, **params)
        else:
            x1_norm = x1.pow(2).sum(dim=-1, keepdim=True)
            x2_norm = x2.pow(2).sum(dim=-1, keepdim=True)
            x1_dot_x2 = torch.matmul(x1 , x2.transpose(-1, -2))
            denominator = x1_norm + x2_norm.transpose(-1, -2) - x1_dot_x2
            return x1_dot_x2 / denominator.clamp(min=1e-8)


class GPRegressionModel(gpytorch.models.ExactGP):
    """
    A Gaussian Process Regression model using a Tanimoto kernel.

    This model is designed for exact GP inference and is particularly suited for
    regression tasks with binary feature vectors, such as molecular fingerprints.

    Attributes:
    -----------
    mean_module : gpytorch.means.ConstantMean
        The mean function of the Gaussian Process.
    covar_module : TanimotoKernel
        The covariance function (kernel) of the Gaussian Process.

    Methods:
    --------
    forward(x)
        Defines the computation performed at every call.
    """

    def __init__(self, train_x, train_y, likelihood):
        """
        Initialize the GPRegressionModel.

        Parameters:
        -----------
        train_x : torch.Tensor
            The training input data.
        train_y : torch.Tensor
            The training target data.
        likelihood : gpytorch.likelihoods.Likelihood
            The likelihood for the Gaussian Process model.
        """
        super(GPRegressionModel, self).__init__(train_x, train_y, likelihood)
        self.mean_module = gpytorch.means.ConstantMean()

        #self.covar_module = gpytorch.kernels.ScaleKernel(gpytorch.kernels.MaternKernel())
        
        self.covar_module = gpytorch.kernels.ScaleKernel(gpytorch.kernels.LinearKernel())
        print("Linear kernel")

        # self.covar_module = gpytorch.kernels.ScaleKernel(TanimotoKernel())
        # print("Tanimoto kernel")

        #self.covar_module = gpytorch.kernels.ScaleKernel(gpytorch.kernels.RBFKernel())
        #print("RBF kernel")

        #self.covar_module =  gpytorch.kernels.ScaleKernel(gpytorch.kernels.RQKernel())
        #print("RQ kernel")

        #self.covar_module = gpytorch.kernels.ScaleKernel(BraunBlanquetKernel())
        # #self.covar_module = gpytorch.kernels.ScaleKernel(gpytorch.kernels.CosineKernel())

    

        

    def forward(self, x):
        """
        Defines the computation performed at every call.

        This method specifies how input data is transformed into a distribution
        over output data.

        Parameters:
        -----------
        x : torch.Tensor
            The input data.

        Returns:
        --------
        gpytorch.distributions.MultivariateNormal
            A multivariate normal distribution representing the GP posterior.
        """
        mean_x = self.mean_module(x)
        covar_x = self.covar_module(x)
        return gpytorch.distributions.MultivariateNormal(mean_x, covar_x)

# %%
# Set manual seed since nn.Parameter are randomly initialized
torch.manual_seed(42)

# Create an instance of the model (this is a subclass of nn.Module that contains nn.Parameter(s))
model_0 = GPRegressionModel(X_train, Y_sars, gpytorch.likelihoods.GaussianLikelihood())

# Check the nn.Parameter(s) within the nn.Module subclass we created
list(model_0.parameters())
# Out:
# Linear kernel
# [Parameter containing:
#  tensor([0.], requires_grad=True),
#  Parameter containing:
#  tensor(0., requires_grad=True),
#  Parameter containing:
#  tensor(0., requires_grad=True),
#  Parameter containing:
#  tensor([[0.]], requires_grad=True)]

# %%
# List named parameters 
model_0.state_dict()
# Out:
# OrderedDict([('likelihood.noise_covar.raw_noise', tensor([0.])),
#              ('likelihood.noise_covar.raw_noise_constraint.lower_bound',
#               tensor(1.0000e-04)),
#              ('likelihood.noise_covar.raw_noise_constraint.upper_bound',
#               tensor(inf)),
#              ('mean_module.raw_constant', tensor(0.)),
#              ('covar_module.raw_outputscale', tensor(0.)),
#              ('covar_module.base_kernel.raw_variance', tensor([[0.]])),
#              ('covar_module.base_kernel.raw_variance_constraint.lower_bound',
#               tensor(0.)),
#              ('covar_module.base_kernel.raw_variance_constraint.upper_bound',
#               tensor(inf)),
#              ('covar_module.raw_outputscale_constraint.lower_bound',
#               tensor(0.)),
#              ('covar_module.raw_outputscale_constraint.upper_bound',
#               tensor(inf))])

# %%
from utils import *
from gpregression import GPRegressionModel

def train_gp_model(train_x, train_y, likelihood, model, epochs, lr, lr_decay):
    device = train_x.device
    model = model.to(device)
    likelihood = likelihood.to(device)

    model.train()
    likelihood.train()

    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=lr_decay)
    mll = gpytorch.mlls.ExactMarginalLogLikelihood(likelihood, model)
    
    losses = []
    for i in range(epochs):
        optimizer.zero_grad()
        output = model(train_x)
        loss = - mll(output, train_y)
        losses.append(loss.item())
        if (i+1) % 10 == 0:
            print(f"Epoch {i+1}/{epochs} | Loss: {loss.item():.3f}")
            # Log training loss to wandb
            # wandb.log({"train_loss": loss.item(), "epoch": i+1})
        loss.backward()
        optimizer.step()
        scheduler.step()

    return model, likelihood, losses

# %%
likelihood = gpytorch.likelihoods.GaussianLikelihood()
model = GPRegressionModel(X_train, Y_mers, likelihood)
# Out:
# Linear kernel

# %%
train_gp_model(train_x= X_train, train_y=Y_mers, likelihood=likelihood, model=model_0, epochs=100, lr=0.1, lr_decay=0.95)
# Out:
# Epoch 10/100 | Loss: 1.527
# Epoch 20/100 | Loss: 1.337
# Epoch 30/100 | Loss: 1.256
# Epoch 40/100 | Loss: 1.220
# Epoch 50/100 | Loss: 1.201
# Epoch 60/100 | Loss: 1.192
# Epoch 70/100 | Loss: 1.186
# Epoch 80/100 | Loss: 1.183
# Epoch 90/100 | Loss: 1.181
# Epoch 100/100 | Loss: 1.180
# (GPRegressionModel(
#    (likelihood): GaussianLikelihood(
#      (noise_covar): HomoskedasticNoise(
#        (raw_noise_constraint): GreaterThan(1.000E-04)
#      )
#    )
#    (mean_module): ConstantMean()
#    (covar_module): ScaleKernel(
#      (base_kernel): LinearKernel(
#        (raw_variance_constraint): Positive()
#      )
#      (raw_outputscale_constraint): Positive()
#    )
#  ),
#  GaussianLikelihood(
#    (noise_covar): HomoskedasticNoise(
#      (raw_noise_constraint): GreaterThan(1.000E-04)
#    )
#  ),
#  [1.8799983263015747,
#   1.8299258947372437,
#   1.782646656036377,
#   1.7381614446640015,
#   1.6964445114135742,
#   1.657444953918457,
#   1.6210910081863403,
#   1.5872920751571655,
#   1.5559442043304443,
#   1.526931643486023,
#   1.5001304149627686,
#   1.4754127264022827,
#   1.4526476860046387,
#   1.431705117225647,
#   1.4124565124511719,
#   1.3947774171829224,
#   1.3785479068756104,
#   1.3636530637741089,
#   1.349985122680664,
#   1.3374425172805786,
#   1.3259303569793701,
#   1.3153607845306396,
#   1.3056526184082031,
#   1.2967307567596436,
#   1.2885265350341797,
#   1.2809768915176392,
#   1.274024486541748,
#   1.2676169872283936,
#   1.2617063522338867,
#   1.2562495470046997,
#   1.2512071132659912,
#   1.2465429306030273,
#   1.242224931716919,
#   1.2382234334945679,
#   1.2345118522644043,
#   1.2310659885406494,
#   1.2278637886047363,
#   1.2248852252960205,
#   1.2221121788024902,
#   1.219528317451477,
#   1.2171183824539185,
#   1.2148689031600952,
#   1.212767481803894,
#   1.210802674293518,
#   1.208964228630066,
#   1.2072428464889526,
#   1.205629587173462,
#   1.204116702079773,
#   1.2026970386505127,
#   1.2013640403747559,
#   1.2001112699508667,
#   1.1989336013793945,
#   1.19782555103302,
#   1.1967827081680298,
#   1.1958004236221313,
#   1.194874882698059,
#   1.1940022706985474,
#   1.1931791305541992,
#   1.1924023628234863,
#   1.1916691064834595,
#   1.1909765005111694,
#   1.1903221607208252,
#   1.1897038221359253,
#   1.1891189813613892,
#   1.1885658502578735,
#   1.188042402267456,
#   1.1875470876693726,
#   1.1870781183242798,
#   1.1866340637207031,
#   1.1862132549285889,
#   1.185814619064331,
#   1.1854368448257446,
#   1.185078740119934,
#   1.1847392320632935,
#   1.1844172477722168,
#   1.1841117143630981,
#   1.1838219165802002,
#   1.1835469007492065,
#   1.1832859516143799,
#   1.1830382347106934,
#   1.1828031539916992,
#   1.182579755783081,
#   1.1823679208755493,
#   1.182166576385498,
#   1.181975245475769,
#   1.1817936897277832,
#   1.1816211938858032,
#   1.1814571619033813,
#   1.1813013553619385,
#   1.181153416633606,
#   1.1810126304626465,
#   1.18087899684906,
#   1.1807518005371094,
#   1.1806310415267944,
#   1.180516242980957,
#   1.1804070472717285,
#   1.1803032159805298,
#   1.1802046298980713,
#   1.1801106929779053,
#   1.1800215244293213])

# %%
# Find our model's learned parameters
print("The model learned the following values for weights and bias:")
print(model_0.state_dict())
# Out:
# The model learned the following values for weights and bias:
# OrderedDict([('likelihood.noise_covar.raw_noise', tensor([0.])), ('likelihood.noise_covar.raw_noise_constraint.lower_bound', tensor(1.0000e-04)), ('likelihood.noise_covar.raw_noise_constraint.upper_bound', tensor(inf)), ('mean_module.raw_constant', tensor(2.2039)), ('covar_module.raw_outputscale', tensor(-1.8107)), ('covar_module.base_kernel.raw_variance', tensor([[-1.8107]])), ('covar_module.base_kernel.raw_variance_constraint.lower_bound', tensor(0.)), ('covar_module.base_kernel.raw_variance_constraint.upper_bound', tensor(inf)), ('covar_module.raw_outputscale_constraint.lower_bound', tensor(0.)), ('covar_module.raw_outputscale_constraint.upper_bound', tensor(inf))])

# %%
# Get into evaluation (predictive posterior) mode
model.eval()
likelihood.eval()

# Test points are regularly spaced along [0,1]
# Make predictions by feeding model through likelihood
with torch.no_grad(), gpytorch.settings.fast_pred_var():
    observed_pred = likelihood(model(X_test))
    print(observed_pred)
# Out:
# MultivariateNormal(loc: torch.Size([297]))

# %%
f_preds = model(X_test)

# %%
f_preds = model(X_test)
y_preds = likelihood(model(X_test))

f_mean = f_preds.mean
f_var = f_preds.variance
f_covar = f_preds.covariance_matrix

# %%
y = observed_pred.sample(sample_shape=torch.Size([297])).t().cpu().numpy()
y
# Out:
# array([[7.5382614, 6.937912 , 6.1369104, ..., 3.9305768, 4.841963 ,
#         7.6663914],
#        [4.8866377, 5.5662346, 5.340426 , ..., 3.6716757, 4.687453 ,
#         4.7186503],
#        [9.143856 , 5.5963736, 2.6856892, ..., 9.226816 , 2.9517777,
#         6.3229823],
#        ...,
#        [5.378458 , 3.094327 , 3.5206485, ..., 4.130957 , 3.089272 ,
#         4.9799156],
#        [5.5422926, 6.0765343, 6.846983 , ..., 5.777278 , 5.2453904,
#         5.266298 ],
#        [5.1698117, 8.34744  , 7.4437833, ..., 7.868406 , 6.7497234,
#         5.7736297]], dtype=float32)

# %%
len(X_train), len(Y_sars), len(Y_mers)
# Out:
# (712, 712, 712)

# %% [markdown]
# # Correct code starts from here

# %%
"""
Antiviral Potency Prediction Model
----------------------------------
This code predicts the potency (pIC50) of molecules against coronavirus main proteases
using Gaussian Process Regression with molecular fingerprints.
"""

import os
import sys
import numpy as np
import pandas as pd
import torch
import gpytorch

# -----------------------------------------------
# Setup Paths and Import Dependencies
# -----------------------------------------------

def setup_environment():
    """Set up the environment and import necessary modules."""
    # Navigate to project root
    root_dir = os.path.abspath(os.path.join(os.getcwd(), "DD"))
    sys.path.append(root_dir)
    
    # Import project utilities
    import polaris as po
    
    return po

# -----------------------------------------------
# Data Loading and Preprocessing
# -----------------------------------------------

def load_competition_data(po):
    """Load the competition data and cache it."""
    CHALLENGE = "antiviral-potency-2025"
    competition = po.load_competition(f"asap-discovery/{CHALLENGE}")
    competition.cache()
    
    return competition

def prepare_dataset(competition):
    """Prepare the training and testing datasets."""
    # Get train-test split
    train, test = competition.get_train_test_split()
    
    # Extract data into lists
    smiles = []
    pIC50_MERS = []
    pIC50_SARS = []
    
    for i in range(len(train)):
        item = train[i]
        smiles.append(item[0])
        pIC50_MERS.append(item[1]['pIC50 (MERS-CoV Mpro)'])
        pIC50_SARS.append(item[1]['pIC50 (SARS-CoV-2 Mpro)'])
    
    # Create and clean DataFrame
    mpro_df = pd.DataFrame({
        'SMILES': smiles,
        'pIC50_MERS': pIC50_MERS,
        'pIC50_SARS': pIC50_SARS
    })
    mpro_df = mpro_df.dropna()  # Remove rows with missing values
    
    return mpro_df, test

# %%
def convert_to_fingerprints(mpro_df, test, dm):
    """Convert SMILES to molecular fingerprints and prepare tensors."""
    # Prepare training data
    X_train = np.array([dm.to_fp(dm.to_mol(smi)) for smi in mpro_df['SMILES']])
    Y_sars = mpro_df['pIC50_SARS']
    Y_mers = mpro_df['pIC50_MERS']
    
    # Prepare test data
    X_test = np.array([dm.to_fp(dm.to_mol(smi)) for smi in test.X])
    
    # Convert to PyTorch tensors
    X_train_tensor = torch.tensor(X_train, dtype=torch.uint8)
    Y_sars_tensor = torch.tensor(Y_sars.to_numpy(), dtype=torch.float32)
    Y_mers_tensor = torch.tensor(Y_mers.to_numpy(), dtype=torch.float32)
    X_test_tensor = torch.tensor(X_test, dtype=torch.uint8)
    
    return X_train_tensor, Y_sars_tensor, Y_mers_tensor, X_test_tensor

# %%
# -----------------------------------------------
# Kernel Definitions
# -----------------------------------------------

class TanimotoKernel(gpytorch.kernels.Kernel):
    """
    A custom kernel implementing the Tanimoto similarity for GPyTorch models.
    
    The Tanimoto kernel is particularly useful for binary data, such as molecular fingerprints.
    It computes the similarity between two binary vectors using the Tanimoto coefficient.
    """
    
    def __init__(self, **kwargs):
        """Initialize the TanimotoKernel."""
        super(TanimotoKernel, self).__init__(**kwargs)
        self.register_parameter(name="raw_lengthscale", parameter=torch.nn.Parameter(torch.zeros(1)))
    
    def forward(self, x1, x2, diag=False, **params):
        """Compute the Tanimoto similarity between two sets of inputs."""
        if diag:
            return self.covar_dist(x1, x2, diag=True, **params)
        else:
            x1_norm = x1.pow(2).sum(dim=-1, keepdim=True)
            x2_norm = x2.pow(2).sum(dim=-1, keepdim=True)
            x1_dot_x2 = torch.matmul(x1, x2.transpose(-1, -2))
            denominator = x1_norm + x2_norm.transpose(-1, -2) - x1_dot_x2
            return x1_dot_x2 / denominator.clamp(min=1e-8)

# -----------------------------------------------
# Model Definition
# -----------------------------------------------

class GPRegressionModel(gpytorch.models.ExactGP):
    """
    A Gaussian Process Regression model with configurable kernels.
    
    This model is designed for exact GP inference and is particularly suited for
    regression tasks with molecular fingerprints.
    """
    
    def __init__(self, train_x, train_y, likelihood, kernel_type="linear"):
        """
        Initialize the GPRegressionModel.
        
        Parameters:
        -----------
        train_x : torch.Tensor
            The training input data.
        train_y : torch.Tensor
            The training target data.
        likelihood : gpytorch.likelihoods.Likelihood
            The likelihood for the Gaussian Process model.
        kernel_type : str
            The type of kernel to use ('linear', 'tanimoto', 'rbf', 'rq', etc.)
        """
        super(GPRegressionModel, self).__init__(train_x, train_y, likelihood)
        self.mean_module = gpytorch.means.ConstantMean()
        
        # Select kernel based on kernel_type
        if kernel_type == "linear":
            self.covar_module = gpytorch.kernels.ScaleKernel(gpytorch.kernels.LinearKernel())
            print("Using Linear kernel")
        elif kernel_type == "tanimoto":
            self.covar_module = gpytorch.kernels.ScaleKernel(TanimotoKernel())
            print("Using Tanimoto kernel")
        elif kernel_type == "rbf":
            self.covar_module = gpytorch.kernels.ScaleKernel(gpytorch.kernels.RBFKernel())
            print("Using RBF kernel")
        elif kernel_type == "matern":
            self.covar_module = gpytorch.kernels.ScaleKernel(gpytorch.kernels.MaternKernel())

            print("Using Matern kernel")
        elif kernel_type == "rq":
            self.covar_module = gpytorch.kernels.ScaleKernel(gpytorch.kernels.RQKernel())
            print("Using RQ kernel")
        else:
            # Default to linear kernel
            self.covar_module = gpytorch.kernels.ScaleKernel(gpytorch.kernels.LinearKernel())
            print(f"Unknown kernel '{kernel_type}', using Linear kernel as default")
    
    def forward(self, x):
        """Define the computational graph for the GP model."""
        mean_x = self.mean_module(x)
        covar_x = self.covar_module(x)
        return gpytorch.distributions.MultivariateNormal(mean_x, covar_x)

# %%
# -----------------------------------------------
# Training Functions
# -----------------------------------------------

def train_gp_model(train_x, train_y, likelihood, model, epochs=100, lr=0.1, lr_decay=0.95):
    """
    Train a Gaussian Process regression model.
    
    Parameters:
    -----------
    train_x : torch.Tensor
        Training input data.
    train_y : torch.Tensor
        Training target values.
    likelihood : gpytorch.likelihoods.GaussianLikelihood
        The likelihood for the GP model.
    model : GPRegressionModel
        The GP model to train.
    epochs : int
        Number of training epochs.
    lr : float
        Initial learning rate.
    lr_decay : float
        Learning rate decay factor.
        
    Returns:
    --------
    model : GPRegressionModel
        Trained GP model.
    likelihood : gpytorch.likelihoods.GaussianLikelihood
        Trained likelihood.
    losses : list
        Training loss history.
    """
    device = train_x.device
    model = model.to(device)
    likelihood = likelihood.to(device)
    
    model.train()
    likelihood.train()
    
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=lr_decay)
    mll = gpytorch.mlls.ExactMarginalLogLikelihood(likelihood, model)
    
    losses = []
    for i in range(epochs):
        optimizer.zero_grad()
        output = model(train_x)
        loss = -mll(output, train_y)
        losses.append(loss.item())
        
        if (i+1) % 10 == 0:
            print(f"Epoch {i+1}/{epochs} | Loss: {loss.item():.3f}")
        
        loss.backward()
        optimizer.step()
        scheduler.step()
    
    return model, likelihood, losses

# %%
# -----------------------------------------------
# Prediction Functions
# -----------------------------------------------

def make_predictions(model, likelihood, X_test):
    """
    Make predictions using a trained GP model.
    
    Parameters:
    -----------
    model : GPRegressionModel
        Trained GP model.
    likelihood : gpytorch.likelihoods.GaussianLikelihood
        Trained likelihood.
    X_test : torch.Tensor
        Test input data.
        
    Returns:
    --------
    f_mean : torch.Tensor
        Mean predictions.
    f_var : torch.Tensor
        Prediction variances.
    f_samples : torch.Tensor
        Samples from the posterior.
    """
    model.eval()
    likelihood.eval()
    
    with torch.no_grad(), gpytorch.settings.fast_pred_var():
        # Get predictive distribution
        f_preds = model(X_test)
        y_preds = likelihood(model(X_test))
        print(y_preds)
        
        # Extract statistics
        f_mean = f_preds.mean
        f_var = f_preds.variance
        
        # Draw samples from the posterior
        f_samples = y_preds.sample(sample_shape=torch.Size([X_test.shape[0]])).t()
    
    return f_mean, f_var, f_samples

# %%
po = setup_environment()

# %%
def main():
    """Main execution function that handles both targets and submission."""
    # Setup environment
    po = setup_environment()
    from utils import dm  # Import dm here after environment setup
    
    # Load and prepare data
    competition = load_competition_data(po)
    mpro_df, test = prepare_dataset(competition)
    X_train, Y_sars, Y_mers, X_test = convert_to_fingerprints(mpro_df, test, dm)
    
    # Set seed for reproducibility
    torch.manual_seed(42)
    kernel_type = "linear"

    # Train model for SARS-CoV-2
    likelihood_sars = gpytorch.likelihoods.GaussianLikelihood()
    model_sars = GPRegressionModel(X_train, Y_sars, likelihood_sars, kernel_type="linear")
    model_sars, likelihood_sars, losses_sars = train_gp_model(
        train_x=X_train,
        train_y=Y_sars,
        likelihood=likelihood_sars,
        model=model_sars,
        epochs=100,
        lr=0.1,
        lr_decay=0.95
    )
    # Plot training loss
    plt.figure(figsize=(10, 6))
    plt.plot(losses_sars)
    plt.title(f'SARS Model Training Loss_ {kernel_type}')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.grid(True)
    plt.show()

    
    
    # Train model for MERS-CoV
    likelihood_mers = gpytorch.likelihoods.GaussianLikelihood()
    model_mers = GPRegressionModel(X_train, Y_mers, likelihood_mers, kernel_type="linear")
    model_mers, likelihood_mers, losses_mers = train_gp_model(
        train_x=X_train,
        train_y=Y_mers,
        likelihood=likelihood_mers,
        model=model_mers,
        epochs=100,
        lr=0.1,
        lr_decay=0.95
    )
    

    # Plot training loss
    plt.figure(figsize=(10, 6))
    plt.plot(losses_mers)
    plt.title(f'MERS Model Training Loss _ {kernel_type}')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.grid(True)
    plt.show()

    # Generate predictions for both targets
    model_sars.eval()
    likelihood_sars.eval()
    model_mers.eval()
    likelihood_mers.eval()
    
    with torch.no_grad(), gpytorch.settings.fast_pred_var():
        # SARS-CoV-2 predictions
        f_preds_sars = model_sars(X_test)
        mean_sars = f_preds_sars.mean.cpu().numpy()
        
        # MERS-CoV predictions
        f_preds_mers = model_mers(X_test)
        mean_mers = f_preds_mers.mean.cpu().numpy()
    
    # Create prediction dictionary for submission
    y_pred = {
        'pIC50 (SARS-CoV-2 Mpro)': mean_sars,
        'pIC50 (MERS-CoV Mpro)': mean_mers
    }
    
    # Submit predictions
    competition.submit_predictions(
        predictions=y_pred,
        prediction_name="gp-model-baseline",
        prediction_owner="caithmac",  # Replace with your username
        report_url="https://github.com/caithmac/polaris_potency_mpro",  # Optional, can be empty for now
        description="Gaussian Process Regression baseline with linear kernel",
        tags=["baseline", "gp-regression"],
        user_attributes={"Framework": "GPyTorch", "Method": "Gaussian Process Regression"}
    )
    
    print("Submission completed successfully!")
    
    return model_sars, model_mers, y_pred

if __name__ == "__main__":
    model_sars, model_mers, predictions = main()
# Out:
# [2025-03-02 18:46:26] INFO     The version of Polaris that was used to create the artifact (0.11.0) ]8;id=163533;file:///home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/polaris/_artifact.py\_artifact.py]8;;\:]8;id=567418;file:///home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/polaris/_artifact.py#92\92]8;;\
#                                is different from the currently installed version of Polaris
#                                (0.11.9).
#                       WARNING  You're loading data from a remote location. If the dataset is small     ]8;id=58302;file:///home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/polaris/dataset/_base.py\_base.py]8;;\:]8;id=88936;file:///home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/polaris/dataset/_base.py#181\181]8;;\
#                                enough, consider caching the dataset first using
#                                CompetitionSpecification.cache() for more performant data access.
# [18:46:26] Copying to destination                                                                      ]8;id=853716;file:///home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/polaris/dataset/_base.py\_base.py]8;;\:]8;id=624363;file:///home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/polaris/dataset/_base.py#380\380]8;;\
#            /home/zeus/.cache/polaris/datasets/decf747d-4962-4f34-84d4-ad0783e1f421/data.zarr
#            For large Zarr archives, this may take a while.                                             ]8;id=571070;file:///home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/polaris/dataset/_base.py\_base.py]8;;\:]8;id=373665;file:///home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/polaris/dataset/_base.py#381\381]8;;\
#             Success: Copying Zarr keys                                                                ]8;id=883220;file:///home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/polaris/utils/context.py\context.py]8;;\:]8;id=870368;file:///home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/polaris/utils/context.py#53\53]8;;\
#             Success: Copying Zarr archive                                                             ]8;id=99557;file:///home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/polaris/utils/context.py\context.py]8;;\:]8;id=622846;file:///home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/polaris/utils/context.py#53\53]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Using Linear kernel
# Epoch 10/100 | Loss: 1.487
# Epoch 20/100 | Loss: 1.259
# Epoch 30/100 | Loss: 1.172
# Epoch 40/100 | Loss: 1.139
# Epoch 50/100 | Loss: 1.124
# Epoch 60/100 | Loss: 1.117
# Epoch 70/100 | Loss: 1.114
# Epoch 80/100 | Loss: 1.112
# Epoch 90/100 | Loss: 1.110
# Epoch 100/100 | Loss: 1.110
# Using Linear kernel
# Epoch 10/100 | Loss: 1.459
# Epoch 20/100 | Loss: 1.214
# Epoch 30/100 | Loss: 1.113
# Epoch 40/100 | Loss: 1.074
# Epoch 50/100 | Loss: 1.057
# Epoch 60/100 | Loss: 1.048
# Epoch 70/100 | Loss: 1.044
# Epoch 80/100 | Loss: 1.041
# Epoch 90/100 | Loss: 1.039
# Epoch 100/100 | Loss: 1.038
# [18:46:40]  Success: Submitting competition predictions                                               ]8;id=273509;file:///home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/polaris/utils/context.py\context.py]8;;\:]8;id=769993;file:///home/zeus/miniconda3/envs/cloudspace/lib/python3.10/site-packages/polaris/utils/context.py#53\53]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Submission completed successfully!
