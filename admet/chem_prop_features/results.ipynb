# %%
import pandas as pd
import seaborn as sns

# %%
results = pd.read_csv('single_task_logistic_ordinal.csv')

sns.relplot(data=results, x='alpha', y='mae', col='target', kind='line')

# %%
results
# Out:
#      target  alpha       mae
# 0    LogHLM    0.1  2.669107
# 1    LogHLM    0.6  2.659114
# 2    LogHLM    1.1  2.646908
# 3    LogHLM    1.6  2.635509
# 4    LogHLM    2.1  2.624813
# ..      ...    ...       ...
# 995    LogD   97.6  2.432773
# 996    LogD   98.1  2.432534
# 997    LogD   98.6  2.432291
# 998    LogD   99.1  2.432044
# 999    LogD   99.6  2.431794
#
# [1000 rows x 3 columns]
